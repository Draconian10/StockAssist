# %% [markdown]
# # Data Gathering, Scraping, Munging and Cleaning for StockAssist

# %% [markdown]
# ## Introduction
# Here, we are searching for authentic sources of data which will be useful for analyzing stock market data. These sources need to be verified in order to generate an accurate analysis upon the stocks. First of all, these multiple data sources need to be scraped in the format available. Once we obtain all the data from multiple data sources, this raw data is supposed to be refined into content or formats better suited for consumption for our database. Finally, this data is cleaned by detecting corrupt or inaccurate records from the dataset and then replacing, modifying or deleting this coarse data.

# %% [markdown]
# ## Data Scraping
# Data Scraping is a technique used to extract data from the internet into a file or spreadsheet. We will be scraping data from the following three sources:
# - Data Scraping from a CSV File
# - Web Scraping
# - Data Scraping using an API

# %% [markdown]
# ### Data Scraping from a CSV File

# %%
import pandas as pd
import mysql.connector # Library required for connecting to the MySQL Database
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Connecting to the MySQL Database
mydb = mysql.connector.connect(host='localhost', user = 'root', passwd = 'Northeastern@NEU10', database = 'stockassist')
mycursor = mydb.cursor()

# %%
# Read data from the CSV file and insert it into a DataFrame
csv_df = pd.read_csv('Ticker_Master.csv')

# %%
# Display data in the DataFrame
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
# 2    ABT       Abbott  Health Care     Health Care Equipment
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed  Health Care     Health Care Equipment
#
#      Headquarters Location      Founded
# 0    Saint Paul, Minnesota         1902
# 1     Milwaukee, Wisconsin         1916
# 2  North Chicago, Illinois         1888
# 3  North Chicago, Illinois  2013 (1888)
# 4   Danvers, Massachusetts         1981

# %% [markdown]
# ### Web Scraping
# We will be performing web scraping using Beautiful Soup which is a Python library for extracting data from HTML and XML files. It works with the parser to provide idiomatic ways of navigating, searching and modifying the parse tree.

# %%
import requests # Library required to send HTTP requests
from bs4 import BeautifulSoup # Library required for performing web scraping using Beautiful Soup

# %%
# Sending HTTP request to the webpage which is supposed to be scraped
request = requests.get('https://www.marketbeat.com/types-of-stock/sp-500-stocks/')

# %%
# Connecting to the webpage via Beautiful Soup using the HTML parser
soup = BeautifulSoup(request.content, 'html.parser')

# %%
# Converting Beautiful Soup parse tree into a nicely formatted Unicode string
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    S&amp;P 500 Stocks | List of Companies
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1.0" name="viewport"/>
#   <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge" /><![endif]-->
#   <meta content="21tyd2NTsebvto7W56gttKaElQtkak0Ld32xGvr_COs" name="google-site-verification"/>
#   <meta content="43C334F81BEB9DE14F872D6C91B4FC29" name="msvalidate.01"/>
#   <meta content="63e01d3704030089" name="y_key"/>
#   <meta content="1450892295227696" property="fb:pages"/>
#   <meta content="#24778c" name="theme-color"/>
#   <meta content="app-id=917482225" name="apple-itunes-app"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <link href="https://www.marketbeat.com/Sitemap.ashx" rel="sitemap" title="Sitemap" type="application/xml"/>
#   <link href="https://www.marketbeat.com/rss.ashx?type=headlines" rel="alternate" title="MarketBeat Headlines RSS" type="application/rss+xml"/>
#   <link href="/images/2favicon.png" rel="shortcut icon"/>
#   <link href="/images/icons/apple-touch-icon-180x180.png" rel="apple-touch-icon"/>
#   <link href="https://www.marketbeat.com/Sitemap.ashx" rel="sitemap"/>
#   <link as="font" crossorigin="" href="/Style/fonts/Prata.woff2?2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/Style/fonts/Yantramanav-400.woff2?2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/Style/fonts/Yantramanav-900.woff2?2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/Style/fonts/Yantramanav-700.woff2?2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/Style/fonts/Oswald.woff2?2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/Style/icon-font/mb-icons.ttf?20210621" rel="preload" type="font/ttf"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <link href="/Style/allstyles9.css?v=20221212" rel="stylesheet"/>
#   <!--[if lt IE 9]>
#         <link rel="stylesheet" href="/Style/olderbrowsers/css/bootstrap.min.css" media="all" />
#         <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#         <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#   <!--[if IE]>
#     <style>
#         #left-side-menu.left-showing, #right-side-menu.right-showing {
#              z-index: 30;
#          color: white;
#         }
#     </style>
#     <![endif]-->
#   <!--[if lt IE 9]>
#       <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#     <![endif]-->
#   <!--[if (gte IE 9) | (!IE)]><!-->
#   <script defer="" src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js">
#   </script>
#   <!--<![endif]-->
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <link href="/manifest.json" rel="manifest"/>
#   <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script src="/scripts/modal/mb-modernpopup.js?v=20221213" type="text/javascript">
#   </script>
#   <script>
#    function registerUserChange(action) {
#            OneSignal.getUserId(function (userId) {
#                OneSignalIdString = userId;
#                var Domain = 'marketbeat.com';
#                var url = "https://www.marketbeat.com/scripts/OneSignalTracking.ashx?OneSignalID=" + OneSignalIdString + "&domain=" + Domain + "&action=" + action;
#                var xhr = new XMLHttpRequest();
#                xhr.open('GET', url);
#                xhr.onload = function () {
#                    if (xhr.status !== 200) {
#                        console.log('GET failed.  Returned status of ' + xhr.status);
#                    }
#                    else {
#                        console.log('GET succeeded (' + url + ').  Returned status of ' + xhr.status);
#                    }
#                };
#                xhr.send();
#            });
#        }
#
#        var OneSignal = OneSignal || [];
#        OneSignal.push(
#            function () {
#                OneSignal.init({
#                    appId: "92d0557c-79b3-4742-9ab4-9155a42d6a49",
#                    safari_web_id: 'web.onesignal.auto.24c5a223-602c-4339-a230-554aefc554b5',
#                    autoRegister: false,
#                    autoResubscribe: true,
#                    notifyButton: {
#                        enable: false
#                    },
#                    welcomeNotification: {
#                        "title": "Join Wall Street's Brightest Minds.",
#                        "message": "Receive research in your inbox from top analysts, before the market opens. Click here to learn how.",
#                        "url": "https://www.marketbeat.com/subscribe/subscribe.aspx?ReferralType=OneSignalThankYou&ProductCode=1997t"
#                    },
#                });
#                OneSignal.once('subscriptionChange', function (isSubscribed) {
#                    if (isSubscribed) {
#                        registerUserChange("subscribe");
#                    }
#                    else {
#                        registerUserChange("unsubscribe");
#                    }
#                });
#                if ((navigator.userAgent.toLowerCase().indexOf('firefox') > -1) || ((navigator.userAgent.toLowerCase().indexOf('safari') > -1) && (!(navigator.userAgent.toLowerCase().indexOf('chrome') > -1)))) {
#                    OneSignal.showSlidedownPrompt();
#                } else {
#                    OneSignal.showNativePrompt();
#                }
#            });
#   </script>
#   <script type="application/ld+json">
#    { "@context": "http://schema.org", "@type": "WebPage", "mainEntityOfPage": { "@type": "WebPage", "@id": "https://google.com/webpage" }, "headline": "What Do S&P 500 Stocks Tell Investors About the Market? ", "image": { "@type": "ImageObject", "url": "https://www.marketbeat.com/logos/articles/small_stock-image_345066962_S.jpg", "height": "400", "width": "400" }, "datePublished": "2022-09-16", "dateModified": "2022-12-14", "author": { "@type": "Person", "name": "MarketBeat Staff" }, "publisher": { "@type": "Organization", "name": "MarketBeat", "logo": { "@type": "ImageObject", "url": "https://www.marketbeat.com/images/master/marketbeat-logo-gray-blue.png?v=2019", "width": "334", "height": "100" }}, "description": "View the current S&P 500 companies which make up the Standard and Poor's 500 stock market index, better known as the S&P 500 index." }
#   </script>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@MarketBeatCom" name="twitter:site"/>
#   <meta content="@MarketBeatCom" name="twitter:creator"/>
#   <meta content="What Do S&amp;P 500 Stocks Tell Investors About the Market? " name="twitter:title"/>
#   <meta content="View the current S&amp;P 500 companies which make up the Standard and Poor's 500 stock market index, better known as the S&amp;P 500 index." name="twitter:description"/>
#   <meta content="https://www.marketbeat.com/logos/articles/small_stock-image_345066962_S.jpg" name="twitter:image"/>
#   <meta content="What Do S&amp;P 500 Stocks Tell Investors About the Market? " property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://www.marketbeat.com/types-of-stock/sp-500-stocks/" property="og:url"/>
#   <meta content="https://www.marketbeat.com/logos/articles/small_stock-image_345066962_S.jpg" property="og:image"/>
#   <meta content="View the current S&amp;P 500 companies which make up the Standard and Poor's 500 stock market index, better known as the S&amp;P 500 index." property="og:description"/>
#   <meta content="MarketBeat" property="og:site_name"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="index,follow" name="robots"/>
#   <link href="https://www.marketbeat.com/types-of-stock/sp-500-stocks/" rel="canonical"/>
#   <style type="text/css">
#    @media screen and (min-width:1200px) and (max-width: 1400px) {
#             .temp-hidden{display:none;}
#         }
#   </style>
#   <meta content="http://marketbeat.com/images/marketbeat-logo-400-400.png?v=2022" property="og:image"/>
#   <meta content="400" property="og:image:width"/>
#   <meta content="400" property="og:image:height"/>
#   <style>
#    @media (max-width: 575.9px) {
#             .responsive-header-ad-text {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 display: -webkit-box;
#                 -webkit-box-orient: vertical;
#                 -webkit-line-clamp: 2;
#                 line-height: 1.2;
#                 max-height: 2.4em;
#             }
#         }
#   </style>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-74CWRXG68D">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag() { dataLayer.push(arguments); }
#     gtag('js', new Date());
#     gtag('config', 'G-74CWRXG68D');
#   </script>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9373162611283935">
#   </script>
#   <meta content="View the current S&amp;P 500 companies which make up the Standard and Poor's 500 stock market index, better known as the S&amp;P 500 index." name="description"/>
#   <meta content="Standard and Poor's 500,S&amp;P 500,S&amp;P 500 Stocks" name="keywords"/>
#  </head>
#  <body>
#   <a class="skip-link gradient-purple c-white" href="#main">
#    Skip to main content
#   </a>
#   <div data-auto_select="false" data-cancel_on_tap_outside="true" data-client_id="178542853386-sfq8ta0q9in407qnaud00o1o7a6thlsi.apps.googleusercontent.com" data-login_uri="https://www.marketbeat.com/users/OneTapVerifyRedirect.aspx" data-prompt_parent_id="g_id_onload" data-state_cookie_domain="marketbeat.com" id="g_id_onload" style="position:fixed; z-index: 1501; right:7%; top:33px">
#   </div>
#   <div class="page-wrap">
#    <div aria-label="current prices and price changes for indexes and stocks" class="d-print-none" id="scrollingIndexes" style="max-height: 42px;width:100%;overflow:hidden;">
#     <div class="position-relative index-mover bg-dark-blue c-white" style="white-space: nowrap;">
#      <div class="index-inner-1">
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/QQQ/">
#          QQQ
#         </span>
#        </span>
#        <span class="index-price">
#         286.51
#        </span>
#        <span class="index-change">
#         (-0.74%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AAPL/">
#          AAPL
#         </span>
#        </span>
#        <span class="index-price">
#         143.21
#        </span>
#        <span class="index-change">
#         (-1.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MSFT/">
#          MSFT
#         </span>
#        </span>
#        <span class="index-price">
#         257.22
#        </span>
#        <span class="index-change">
#         (+0.12%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/META/">
#          META
#         </span>
#        </span>
#        <span class="index-price">
#         121.59
#        </span>
#        <span class="index-change">
#         (+1.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/GOOGL/">
#          GOOGL
#         </span>
#        </span>
#        <span class="index-price">
#         95.07
#        </span>
#        <span class="index-change">
#         (-0.59%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMZN/">
#          AMZN
#         </span>
#        </span>
#        <span class="index-price">
#         91.58
#        </span>
#        <span class="index-change">
#         (-0.98%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/TSLA/">
#          TSLA
#         </span>
#        </span>
#        <span class="index-price">
#         156.80
#        </span>
#        <span class="index-change">
#         (-2.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NVDA/">
#          NVDA
#         </span>
#        </span>
#        <span class="index-price">
#         176.74
#        </span>
#        <span class="index-change">
#         (-2.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/NIO/">
#          NIO
#         </span>
#        </span>
#        <span class="index-price">
#         12.10
#        </span>
#        <span class="index-change">
#         (-1.71%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/BABA/">
#          BABA
#         </span>
#        </span>
#        <span class="index-price">
#         90.91
#        </span>
#        <span class="index-change">
#         (-0.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMD/">
#          AMD
#         </span>
#        </span>
#        <span class="index-price">
#         68.93
#        </span>
#        <span class="index-change">
#         (-3.80%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/T/">
#          T
#         </span>
#        </span>
#        <span class="index-price">
#         18.90
#        </span>
#        <span class="index-change">
#         (-1.15%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MU/">
#          MU
#         </span>
#        </span>
#        <span class="index-price">
#         54.59
#        </span>
#        <span class="index-change">
#         (-1.18%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/CGC/">
#          CGC
#         </span>
#        </span>
#        <span class="index-price">
#         2.84
#        </span>
#        <span class="index-change">
#         (-2.41%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/F/">
#          F
#         </span>
#        </span>
#        <span class="index-price">
#         13.48
#        </span>
#        <span class="index-change">
#         (-0.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/GE/">
#          GE
#         </span>
#        </span>
#        <span class="index-price">
#         81.47
#        </span>
#        <span class="index-change">
#         (-1.61%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/DIS/">
#          DIS
#         </span>
#        </span>
#        <span class="index-price">
#         94.15
#        </span>
#        <span class="index-change">
#         (-0.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/AMC/">
#          AMC
#         </span>
#        </span>
#        <span class="index-price">
#         5.75
#        </span>
#        <span class="index-change">
#         (+0.52%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/PFE/">
#          PFE
#         </span>
#        </span>
#        <span class="index-price">
#         54.48
#        </span>
#        <span class="index-change">
#         (+2.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/PYPL/">
#          PYPL
#         </span>
#        </span>
#        <span class="index-price">
#         72.63
#        </span>
#        <span class="index-change">
#         (-1.45%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NFLX/">
#          NFLX
#         </span>
#        </span>
#        <span class="index-price">
#         317.83
#        </span>
#        <span class="index-change">
#         (-0.78%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#      </div>
#      <div class="index-inner-2">
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/QQQ/">
#          QQQ
#         </span>
#        </span>
#        <span class="index-price">
#         286.51
#        </span>
#        <span class="index-change">
#         (-0.74%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AAPL/">
#          AAPL
#         </span>
#        </span>
#        <span class="index-price">
#         143.21
#        </span>
#        <span class="index-change">
#         (-1.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MSFT/">
#          MSFT
#         </span>
#        </span>
#        <span class="index-price">
#         257.22
#        </span>
#        <span class="index-change">
#         (+0.12%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/META/">
#          META
#         </span>
#        </span>
#        <span class="index-price">
#         121.59
#        </span>
#        <span class="index-change">
#         (+1.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/GOOGL/">
#          GOOGL
#         </span>
#        </span>
#        <span class="index-price">
#         95.07
#        </span>
#        <span class="index-change">
#         (-0.59%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMZN/">
#          AMZN
#         </span>
#        </span>
#        <span class="index-price">
#         91.58
#        </span>
#        <span class="index-change">
#         (-0.98%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/TSLA/">
#          TSLA
#         </span>
#        </span>
#        <span class="index-price">
#         156.80
#        </span>
#        <span class="index-change">
#         (-2.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NVDA/">
#          NVDA
#         </span>
#        </span>
#        <span class="index-price">
#         176.74
#        </span>
#        <span class="index-change">
#         (-2.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/NIO/">
#          NIO
#         </span>
#        </span>
#        <span class="index-price">
#         12.10
#        </span>
#        <span class="index-change">
#         (-1.71%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/BABA/">
#          BABA
#         </span>
#        </span>
#        <span class="index-price">
#         90.91
#        </span>
#        <span class="index-change">
#         (-0.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMD/">
#          AMD
#         </span>
#        </span>
#        <span class="index-price">
#         68.93
#        </span>
#        <span class="index-change">
#         (-3.80%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/T/">
#          T
#         </span>
#        </span>
#        <span class="index-price">
#         18.90
#        </span>
#        <span class="index-change">
#         (-1.15%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MU/">
#          MU
#         </span>
#        </span>
#        <span class="index-price">
#         54.59
#        </span>
#        <span class="index-change">
#         (-1.18%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/CGC/">
#          CGC
#         </span>
#        </span>
#        <span class="index-price">
#         2.84
#        </span>
#        <span class="index-change">
#         (-2.41%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/F/">
#          F
#         </span>
#        </span>
#        <span class="index-price">
#         13.48
#        </span>
#        <span class="index-change">
#         (-0.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/GE/">
#          GE
#         </span>
#        </span>
#        <span class="index-price">
#         81.47
#        </span>
#        <span class="index-change">
#         (-1.61%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/DIS/">
#          DIS
#         </span>
#        </span>
#        <span class="index-price">
#         94.15
#        </span>
#        <span class="index-change">
#         (-0.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/AMC/">
#          AMC
#         </span>
#        </span>
#        <span class="index-price">
#         5.75
#        </span>
#        <span class="index-change">
#         (+0.52%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/PFE/">
#          PFE
#         </span>
#        </span>
#        <span class="index-price">
#         54.48
#        </span>
#        <span class="index-change">
#         (+2.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/PYPL/">
#          PYPL
#         </span>
#        </span>
#        <span class="index-price">
#         72.63
#        </span>
#        <span class="index-change">
#         (-1.45%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NFLX/">
#          NFLX
#         </span>
#        </span>
#        <span class="index-price">
#         317.83
#        </span>
#        <span class="index-change">
#         (-0.78%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#      </div>
#      <div class="index-inner-3">
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/QQQ/">
#          QQQ
#         </span>
#        </span>
#        <span class="index-price">
#         286.51
#        </span>
#        <span class="index-change">
#         (-0.74%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AAPL/">
#          AAPL
#         </span>
#        </span>
#        <span class="index-price">
#         143.21
#        </span>
#        <span class="index-change">
#         (-1.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MSFT/">
#          MSFT
#         </span>
#        </span>
#        <span class="index-price">
#         257.22
#        </span>
#        <span class="index-change">
#         (+0.12%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/META/">
#          META
#         </span>
#        </span>
#        <span class="index-price">
#         121.59
#        </span>
#        <span class="index-change">
#         (+1.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/GOOGL/">
#          GOOGL
#         </span>
#        </span>
#        <span class="index-price">
#         95.07
#        </span>
#        <span class="index-change">
#         (-0.59%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMZN/">
#          AMZN
#         </span>
#        </span>
#        <span class="index-price">
#         91.58
#        </span>
#        <span class="index-change">
#         (-0.98%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/TSLA/">
#          TSLA
#         </span>
#        </span>
#        <span class="index-price">
#         156.80
#        </span>
#        <span class="index-change">
#         (-2.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NVDA/">
#          NVDA
#         </span>
#        </span>
#        <span class="index-price">
#         176.74
#        </span>
#        <span class="index-change">
#         (-2.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/NIO/">
#          NIO
#         </span>
#        </span>
#        <span class="index-price">
#         12.10
#        </span>
#        <span class="index-change">
#         (-1.71%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/BABA/">
#          BABA
#         </span>
#        </span>
#        <span class="index-price">
#         90.91
#        </span>
#        <span class="index-change">
#         (-0.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMD/">
#          AMD
#         </span>
#        </span>
#        <span class="index-price">
#         68.93
#        </span>
#        <span class="index-change">
#         (-3.80%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/T/">
#          T
#         </span>
#        </span>
#        <span class="index-price">
#         18.90
#        </span>
#        <span class="index-change">
#         (-1.15%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MU/">
#          MU
#         </span>
#        </span>
#        <span class="index-price">
#         54.59
#        </span>
#        <span class="index-change">
#         (-1.18%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/CGC/">
#          CGC
#         </span>
#        </span>
#        <span class="index-price">
#         2.84
#        </span>
#        <span class="index-change">
#         (-2.41%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/F/">
#          F
#         </span>
#        </span>
#        <span class="index-price">
#         13.48
#        </span>
#        <span class="index-change">
#         (-0.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/GE/">
#          GE
#         </span>
#        </span>
#        <span class="index-price">
#         81.47
#        </span>
#        <span class="index-change">
#         (-1.61%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/DIS/">
#          DIS
#         </span>
#        </span>
#        <span class="index-price">
#         94.15
#        </span>
#        <span class="index-change">
#         (-0.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/AMC/">
#          AMC
#         </span>
#        </span>
#        <span class="index-price">
#         5.75
#        </span>
#        <span class="index-change">
#         (+0.52%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/PFE/">
#          PFE
#         </span>
#        </span>
#        <span class="index-price">
#         54.48
#        </span>
#        <span class="index-change">
#         (+2.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/PYPL/">
#          PYPL
#         </span>
#        </span>
#        <span class="index-price">
#         72.63
#        </span>
#        <span class="index-change">
#         (-1.45%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NFLX/">
#          NFLX
#         </span>
#        </span>
#        <span class="index-price">
#         317.83
#        </span>
#        <span class="index-change">
#         (-0.78%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#      </div>
#      <div class="index-inner-4">
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/QQQ/">
#          QQQ
#         </span>
#        </span>
#        <span class="index-price">
#         286.51
#        </span>
#        <span class="index-change">
#         (-0.74%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AAPL/">
#          AAPL
#         </span>
#        </span>
#        <span class="index-price">
#         143.21
#        </span>
#        <span class="index-change">
#         (-1.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MSFT/">
#          MSFT
#         </span>
#        </span>
#        <span class="index-price">
#         257.22
#        </span>
#        <span class="index-change">
#         (+0.12%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/META/">
#          META
#         </span>
#        </span>
#        <span class="index-price">
#         121.59
#        </span>
#        <span class="index-change">
#         (+1.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/GOOGL/">
#          GOOGL
#         </span>
#        </span>
#        <span class="index-price">
#         95.07
#        </span>
#        <span class="index-change">
#         (-0.59%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMZN/">
#          AMZN
#         </span>
#        </span>
#        <span class="index-price">
#         91.58
#        </span>
#        <span class="index-change">
#         (-0.98%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/TSLA/">
#          TSLA
#         </span>
#        </span>
#        <span class="index-price">
#         156.80
#        </span>
#        <span class="index-change">
#         (-2.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NVDA/">
#          NVDA
#         </span>
#        </span>
#        <span class="index-price">
#         176.74
#        </span>
#        <span class="index-change">
#         (-2.20%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/NIO/">
#          NIO
#         </span>
#        </span>
#        <span class="index-price">
#         12.10
#        </span>
#        <span class="index-change">
#         (-1.71%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/BABA/">
#          BABA
#         </span>
#        </span>
#        <span class="index-price">
#         90.91
#        </span>
#        <span class="index-change">
#         (-0.55%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/AMD/">
#          AMD
#         </span>
#        </span>
#        <span class="index-price">
#         68.93
#        </span>
#        <span class="index-change">
#         (-3.80%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/T/">
#          T
#         </span>
#        </span>
#        <span class="index-price">
#         18.90
#        </span>
#        <span class="index-change">
#         (-1.15%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/MU/">
#          MU
#         </span>
#        </span>
#        <span class="index-price">
#         54.59
#        </span>
#        <span class="index-change">
#         (-1.18%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/CGC/">
#          CGC
#         </span>
#        </span>
#        <span class="index-price">
#         2.84
#        </span>
#        <span class="index-change">
#         (-2.41%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/F/">
#          F
#         </span>
#        </span>
#        <span class="index-price">
#         13.48
#        </span>
#        <span class="index-change">
#         (-0.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/GE/">
#          GE
#         </span>
#        </span>
#        <span class="index-price">
#         81.47
#        </span>
#        <span class="index-change">
#         (-1.61%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/DIS/">
#          DIS
#         </span>
#        </span>
#        <span class="index-price">
#         94.15
#        </span>
#        <span class="index-change">
#         (-0.58%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/AMC/">
#          AMC
#         </span>
#        </span>
#        <span class="index-price">
#         5.75
#        </span>
#        <span class="index-change">
#         (+0.52%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-green">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NYSE/PFE/">
#          PFE
#         </span>
#        </span>
#        <span class="index-price">
#         54.48
#        </span>
#        <span class="index-change">
#         (+2.66%)
#        </span>
#        <span class="mb-icon icon-arrow point-up">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/PYPL/">
#          PYPL
#         </span>
#        </span>
#        <span class="index-price">
#         72.63
#        </span>
#        <span class="index-change">
#         (-1.45%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#       <div class="header-index gradient-red">
#        <span class="index-name">
#         <span class="go-to-data-href pointer bold" data-href="/stocks/NASDAQ/NFLX/">
#          NFLX
#         </span>
#        </span>
#        <span class="index-price">
#         317.83
#        </span>
#        <span class="index-change">
#         (-0.78%)
#        </span>
#        <span class="mb-icon icon-arrow point-down">
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mega-not-showing" id="header-holder">
#     <div class="gradient-blue w-100" id="mb-header">
#      <header aria-label="site heading" class="logo-bar container d-flex flex-wrap align-items-center" id="logobar" role="banner">
#       <div class="py-1 header-left align-items-center order-sm-1 pr-2 flex-grow-1 flex-sm-grow-0">
#        <div class="d-flex align-items-center">
#         <span class="trigger-left menu-button-wrapper">
#          <span class="c-white mb-icon icon-menu-open">
#          </span>
#         </span>
#         <a href="https://www.marketbeat.com" id="header-logo-link" title="MarketBeat">
#          <img alt="MarketBeat home page" class="header-logo" height="76" src="/images/master/MarketBeat-logo-r-white.svg?v=2019" width="300"/>
#         </a>
#        </div>
#       </div>
#       <div class="pl-2 py-1 order-sm-3 text-right header-right" id="headeright">
#        <a aria-label="Sign Up" class="sbbutton purple-button mr-2" href="https://marketbeat.com/subscribe/subscribeallaccess.aspx?ProductCode=aap3997t&amp;ReferralType=HeaderButton">
#         <span class="mb-icon icon-pricetoearnings">
#         </span>
#         <span class="px-1 d-none d-lg-inline">
#          Free Trial
#         </span>
#        </a>
#        <button aria-label="Login to MarketBeat" class="sbbutton green-button login-modal-button" data-target="#pnlLoginCreateModal" data-toggle="modal" onclick="trapFocusInModal('#pnlLoginCreateModal', 'txtLoginOnModalEmail', 'LoginOnModalTab', 'LastLinkOnLoginTab');">
#         <span class="mb-icon icon-menu-login">
#         </span>
#         <span class="px-1 d-none d-lg-inline-block">
#          Log in
#         </span>
#        </button>
#       </div>
#       <div class="py-1 px-0 order-sm-2 flex-grow-1 col-12 col-sm-auto">
#        <form action="/pages/search.aspx" aria-label="Site search" class="input-group dark-bkg" method="get" role="search">
#         <label class="sr-only" for="headerSearch">
#          Search
#         </label>
#         <input class="autocomplete form-control" id="headerSearch" name="query" placeholder="Search for companies, news, or tools" type="text"/>
#         <span id="mainAutocompleteList">
#         </span>
#         <span class="input-group-append position-relative">
#          <span id="headerSearchLoading" style="width: 20px; height: 20px; position: absolute; left: -1.7em; top: 0.4em; display: none;">
#           <img alt="" height="20" loading="lazy" src="/images/loading-gif.gif?v=2" style="filter: brightness(1.5);" width="20"/>
#          </span>
#          <button aria-label="Search" class="gold-button" type="submit">
# ...
#         </span>
#         <span aria-label="Forbes" class="mb-icon icon-featured-forbes" role="img">
#         </span>
#         <span aria-label="Inc. Magazine" class="mb-icon icon-featured-inc" role="img">
#         </span>
#         <span aria-label="Investing.com" class="mb-icon icon-featured-investing" role="img">
#         </span>
#         <span aria-label="Prairie Business" class="mb-icon icon-featured-prairie-business" role="img">
#         </span>
#         <span aria-label="Seeking Alpha" class="mb-icon icon-featured-seeking-alpha" role="img">
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="gradient-blue c-white position-relative" style="font-size: .9em;">
#      <div class="container">
#       <div class="row pt-4 pb-2 justify-content-between">
#        <div class="col-12 col-lg-4 col-xl-3">
#         <div class="row justify-content-between align-items-start align-items-lg-center">
#          <div class="col-12 col-sm-3 col-md-4 col-lg-12 text-center text-md-left">
#           <img alt="MarketBeat - Stock Market News and Research Tools" class="h-auto mb-lg-1 mt-lg-2" id="footer-logo" loading="lazy" src="/images/master/MarketBeat-logo-r-white.svg?v=2019"/>
#          </div>
#          <div class="col-12 col-sm-5 col-md-4 col-lg-12 text-center text-sm-left">
#           <div class="yantramav font-weight-bold mt-2 mt-sm-0 mt-lg-3">
#            Empowering Individual Investors
#           </div>
#           <p class="small my-2">
#            326 E 8th St #105, Sioux Falls, SD 57103
#            <br>
#             contact@marketbeat.com
#             <br>
#              (844) 978-6257
#             </br>
#            </br>
#           </p>
#          </div>
#          <div class="col-12 col-sm-4 col-lg-12 text-center text-sm-left mt-1 mt-lg-4">
#           <ul class="footer-follow nounderline my-0 p-0">
#            <li class="d-inline-block mr-md-1">
#             <a href="https://twitter.com/MarketBeatCom" rel="noopener" target="_blank">
#              <span class="mb-icon icon-share-twitter c-white">
#              </span>
#              <span class="sr-only">
#               Twitter
#              </span>
#             </a>
#            </li>
#            <li class="d-inline-block mr-md-1">
#             <a href="https://www.facebook.com/marketbeatcom/" rel="noopener" target="_blank" title="Follow MarketBeat on Facebook">
#              <span class="mb-icon icon-share-facebook c-white">
#              </span>
#              <span class="sr-only">
#               Facebook
#              </span>
#             </a>
#            </li>
#            <li class="d-inline-block mr-md-1">
#             <a href="https://stocktwits.com/MarketBeat" rel="noopener" target="_blank" title="Follow MarketBeat on Stocktwits">
#              <span class="mb-icon icon-share-stocktwits c-white">
#              </span>
#              <span class="sr-only">
#               StockTwits
#              </span>
#             </a>
#            </li>
#            <li class="d-inline-block mr-md-1">
#             <a href="http://www.financialjuice.com/marketbeat" rel="noopener" target="_blank" title="Follow MarketBeat on Financial Juice">
#              <span class="mb-icon icon-share-financialjuice c-white">
#              </span>
#              <span class="sr-only">
#               Financial Juice
#              </span>
#             </a>
#            </li>
#            <li class="d-inline-block mr-md-1">
#             <a href="https://www.linkedin.com/company/american-consumer-news-llc/" rel="noopener" target="_blank" title="Follow MarketBeat on LinkedIn">
#              <span class="mb-icon icon-share-linkedin c-white">
#              </span>
#              <span class="sr-only">
#               LinkedIn
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-lg-8 col-xl-9 border-top mt-3 pt-3" style="border-color: #eff2f424 !important">
#         <div class="row">
#          <div class="col-6 col-sm-3">
#           <h2 class="mt-1 mb-2 oswald" style="font-size: 1em;">
#            About MarketBeat
#           </h2>
#           <ul class="mx-0 my-1 p-0 list-unstyled" style="font-size: 0.9em;">
#            <li class="my-2">
#             <a class="font-weight-normal" href="/about/">
#              About
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/press-room/">
#              Press Room
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/help/">
#              Help and How-To
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/advertising/">
#              Advertising
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/contact/">
#              Contact
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-6 col-sm-3">
#           <h2 class="mt-1 mb-2 oswald" style="font-size: 1em;">
#            Popular Tools
#           </h2>
#           <ul class="mx-0 my-1 p-0 list-unstyled" style="font-size: 0.9em;">
#            <li class="my-2">
#             <a class="font-weight-normal" href="/stocks/">
#              Company Profiles
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/compare-stocks/">
#              Compare Stocks
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/dividends/calculator/">
#              Dividend Calculator
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/manage/watchlists/">
#              My MarketBeat
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/all-access/stock-screener/">
#              Stock Screener
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-6 col-sm-3">
#           <h2 class="mt-1 mb-2 oswald" style="font-size: 1em;">
#            Financial Calendars
#           </h2>
#           <ul class="mx-0 my-1 p-0 list-unstyled" style="font-size: 0.9em;">
#            <li class="my-2">
#             <a class="font-weight-normal" href="/ratings/">
#              Analyst Ratings
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/dividends/">
#              Dividends
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/earnings/latest/">
#              Earnings
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/insider-trades/">
#              Insider Trades
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/stock-market-holidays/">
#              Stock Market Holidays
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-6 col-sm-3">
#           <h2 class="mt-1 mb-2 oswald" style="font-size: 1em;">
#            Terms &amp; Info
#           </h2>
#           <ul class="mx-0 my-1 p-0 list-unstyled" style="font-size: 0.9em;">
#            <li class="my-2">
#             <a class="font-weight-normal" href="/accessibility/">
#              Accessibility Statement
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/do-not-sell-my-information/">
#              Do Not Sell My Information
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/terms/#privacy-policy">
#              Privacy Policy
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/rss-feeds/">
#              RSS Feeds
#             </a>
#            </li>
#            <li class="my-2">
#             <a class="font-weight-normal" href="/terms">
#              Terms of Service
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-12 mt-3">
#         <p class="small my-0 py-3">
#          © American Consumer News, LLC dba MarketBeat® 2010-2022. All rights reserved.
#         </p>
#         <p class="small my-0 py-3">
#          © 2022 Market data provided is at least 10-minutes delayed and hosted by Barchart Solutions. Information is provided 'as-is' and solely for informational purposes, not for trading purposes or advice, and is delayed. To see all exchange delays and terms of use please see
#          <a href="https://www.barchartmarketdata.com/terms" rel="nofollow">
#           Barchart's disclaimer
#          </a>
#          .
#          <span class="d-none d-sm-inline-block" id="keep-for-checking-size">
#          </span>
#         </p>
#        </div>
#       </div>
#      </div>
#      <img alt="" aria-hidden="true" class="w-100" height="103" loading="lazy" src="/images/corner-gfx-dark-bkg.svg" style="position: absolute; right: 0; bottom: 0; max-width: 100px;" width="100">
#       <img alt="" aria-hidden="true" class="w-100" height="103" loading="lazy" src="/images/corner-gfx-dark-bkg.svg" style="transform: scaleX(-1); position: absolute; left: 0; bottom: 0; max-width: 100px;" width="100">
#       </img>
#      </img>
#     </div>
#    </footer>
#    <div class="menu-closer">
#    </div>
#   </div>
#   <nav aria-label="Main mobile menu" class="gradient-blue c-white" id="left-side-menu" role="navigation">
#   </nav>
#   <div aria-label="User registration and notifications" class="gradient-blue d-none" id="right-side-menu">
#   </div>
#   <script>
#    function CreateOnModalSubmit(token) {
#             console.log(token);
#             if (CheckCreateOnModal("txtCreateOnModalEmail", "createOnModalWarning", "createOnModalVisibleButton")) {
#                 console.log("passed CheckCreateOnModal");
#                 $("#btnCreateOnModal").click();
#             }
#         }
#
#         function LoginOnModalSubmit() {
#             CheckLoginOnModal("txtLoginOnModalEmail", "txtLoginOnModalPassword", "loginOnModalWarning", "btnLoginOnModal");
#             return false;
#         }
#   </script>
#   <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/hellojs/2.0.0-4/hello.all.js">
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#   </script>
#   <script defer="" src="https://code.jquery.com/ui/1.13.0/jquery-ui.min.js">
#   </script>
#   <script defer="" src="/scripts/masterscripts9.js?v=20221203" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var ShowExitPopup = true;
#   </script>
#   <script type="text/javascript">
#    LoadPopupRatings('MB-Popup','marketbeat.com');
#   </script>
#   <script type="text/javascript">
#    setCookie("MarketBeatOptinCookie", 1, 3);
#   </script>
#   <script>
#    var getNewsletterButton = "<button id='mmsubbutton' onclick=\"openIframeModal('MB-Popup', 'marketbeat.com', '', '', '', 'Ratings', 1);\" class='sbbutton m-3 d-block p-2' style='width:calc(100% - 3rem);'>Get Our Newsletter</button>";
#   </script>
#   <script type="text/javascript">
#    var sc_project=7602069;
# var sc_invisible=1;
# var sc_security="74cbf3e8";
# var sc_https=1;
#   </script>
#   <script src="https://www.statcounter.com/counter/counter.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div class="statcounter">
#     <img alt="Web Analytics" class="statcounter" src="//c.statcounter.com/7602069/0/74cbf3e8/1/"/>
#    </div>
#   </noscript>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-3019647-27', 'auto');
#         ga('send', 'pageview');
#   </script>
#   <script>
#    (function(w, d){
#     var id='pdst-capture', n = 'script';
#     if (!d.getElementById(id)){
#     w.pdst = w.pdst || function() {(w.pdst.q = w.pdst.q || []).push(arguments);};
#     var e = d.createElement(n); e.id = id; e.async=1;
#     e.src = 'https://cdn.pdst.fm/ping.min.js';
#     var s = d.getElementsByTagName(n)[0];
#     s.parentNode.insertBefore(e, s);
#     }
#     w.pdst('conf', { key: '9d269a0f43cc4d9e97ea654095eeea1f' })
#     w.pdst('view')
#     })(window, document);
#   </script>
#   <script type="text/javascript">
#    (function () {
#             const second = 1000,
#                 minute = second * 60,
#                 hour = minute * 60,
#                 day = hour * 24;
#
#             let today = new Date(),
#                 eventDate = new Date(Date.UTC(2022, 10, 29, 05, 59, 00, 00)); // must be 5 hours 59 minutes after you want it to end because of time zones and the month is zero indexed
#
#             //end
#
#             const countDown = new Date(eventDate).getTime(),
#                 x = setInterval(function () {
#
#                     if (document.getElementById("countdown") != null) {
#                         const now = new Date().getTime(),
#                             distance = countDown - now;
#
#                         document.getElementById("days").innerText = Math.floor(distance / (day)),
#                             document.getElementById("hours").innerText = Math.floor((distance % (day)) / (hour)),
#                             document.getElementById("minutes").innerText = Math.floor((distance % (hour)) / (minute)),
#                             document.getElementById("seconds").innerText = Math.floor((distance % (minute)) / second);
#
#                         //do something later when date is reached
#                         if (distance < 0) {
#                             clearInterval(x);
#                         }
#                     //seconds
#
#                     }
#                 }, 200)
#         }());
#
#         (function () {
#             if (document.getElementById("countdownIndividual") != null) {
#
#                 const second = 1000,
#                     minute = second * 60,
#                     hour = minute * 60,
#                     day = hour * 24;
#
#
#                 var daysToOffer = 2;
#                 let expirationDate = new Date(new Date().getTime() + (daysToOffer * 24 * 60 * 60 * 1000));
#
#                 if (getCookie("HIExpiration")) {
#                     expirationDate = new Date(getCookie("HIExpiration"));
#                 }
#                 else {
#                     setCookie("HIExpiration", expirationDate.toJSON(), 16)
#                 }
#
#                 //end
#                 const countDown = new Date(expirationDate).getTime(),
#                     x = setInterval(function () {
#
#
#                     const now = new Date().getTime(),
#                         distance = countDown - now;
#
#                     document.getElementById("days").innerText = Math.floor(distance / (day)),
#                         document.getElementById("hours").innerText = Math.floor((distance % (day)) / (hour)),
#                         document.getElementById("minutes").innerText = Math.floor((distance % (hour)) / (minute)),
#                         document.getElementById("seconds").innerText = Math.floor((distance % (minute)) / second);
#
#                     //do something later when date is reached
#                     if (distance < 0) {
#                         clearInterval(x);
#                     }
#                     //seconds
#
#
#                 }, 200)
#         }
#         }());
#   </script>
#  </body>
# </html>

# %%
# Searching for 'table' tags inside the Unicode string
table = soup.find('table', attrs = {'class':'scroll-table sort-table'})
table
# Out:
# <table class="scroll-table sort-table"><thead><tr><th data-clean="Symbol|Company" data-sort="string">Company</th><th data-clean="Current Price|Price Change" data-sort="float">Current Price</th><th data-sort="float">PE Ratio</th><th data-sort="float">Market Cap</th><th data-sort="float">Volume</th><th data-sort="float">Average Volume</th><th data-sort="string">Indicator(s)</th></tr></thead><tbody><tr><td data-clean="AAPL|Apple"><a class="nounderline" href="/stocks/NASDAQ/AAPL/"><div class="company-thumbnail"><img alt="Apple Inc. stock logo" height="53" loading="lazy" src="https://www.marketbeat.com/logos/thumbnail/apple-inc-logo.png" width="80"/></div><div class="ticker-area">AAPL</div><div class="title-area">Apple</div></a></td><td data-clean="$143.21|-1.6%">$143.21<br/><span class="c-red">-1.6%</span></td><td data-sort-value="23.4386252045827">23.44</td><td data-sort-value="2278201.436">$2.28 trillion</td><td data-sort-value="81191994">81.19 million</td><td data-sort-value="87992508">87.99 million</td><td style="width:175px"><a aria-label="An analyst at Oppenheimer Holdings Inc. recently issued a report on AAPL." href="https://www.marketbeat.com/stocks/NASDAQ/AAPL/price-target/" title="An analyst at Oppenheimer Holdings Inc. recently issued a report on AAPL.">Analyst Report</a><br/><a aria-label="AAPL had large increase in short interest during the most recent reporting period." href="https://www.marketbeat.com/short-interest/short-interest-increases/" title="AAPL had large increase in short interest during the most recent reporting period.">Short Interest ↑</a><br/><a aria-label="An analyst at KeyCorp recently updated their earnings estimates for AAPL." href="https://www.marketbeat.com/stocks/NASDAQ/AAPL/price-target/" title="An analyst at KeyCorp recently updated their earnings estimates for AAPL.">Analyst Revision</a><br/></td></tr><tr><td data-clean="MSFT|Microsoft"><a class="nounderline" href="/stocks/NASDAQ/MSFT/"><div class="company-thumbnail"><img alt="Microsoft Co. stock logo" height="41" loading="lazy" src="https://www.marketbeat.com/logos/thumbnail/microsoft-corporation-logo.png" width="80"/></div><div class="ticker-area">MSFT</div><div class="title-area">Microsoft</div></a></td><td data-clean="$257.22|0.1%">$257.22<br/><span class="c-green">+0.1%</span></td><td data-sort-value="27.7176724137931">27.72</td><td data-sort-value="1917439.545">$1.92 trillion</td><td data-sort-value="35039182">35.04 million</td><td data-sort-value="31297301">31.30 million</td><td style="width:175px"><a aria-label="MSFT had large increase in short interest during the most recent reporting period." href="https://www.marketbeat.com/short-interest/short-interest-increases/" title="MSFT had large increase in short interest during the most recent reporting period.">Short Interest ↑</a><br/></td></tr><tr><td data-clean="GOOG|Alphabet"><a class="nounderline" href="/stocks/NASDAQ/GOOG/"><div class="company-thumbnail"><img alt="Alphabet Inc. stock logo" height="28" loading="lazy" src="https://www.marketbeat.com/logos/thumbnail/google-inc-logo.png" width="80"/></div><div class="ticker-area">GOOG</div><div class="title-area">Alphabet</div></a></td><td data-clean="$95.31|-0.6%">$95.31<br/><span class="c-red">-0.6%</span></td><td data-sort-value="18.9276139410188">18.93</td><td data-sort-value="1233597.33">$1.23 trillion</td><td data-sort-value="26173351">26.17 million</td><td data-sort-value="28876988">28.88 million</td><td style="width:175px"><a aria-label="GOOG had large decrease in short interest during the most recent reporting period." href="https://www.marketbeat.com/short-interest/short-interest-decreases/" title="GOOG had large decrease in short interest during the most recent reporting period.">Short Interest ↓</a><br/></td></tr><tr><td data-clean="GOOGL|Alphabet"><a class="nounderline" href="/stocks/NASDAQ/GOOGL/"><div class="company-thumbnail"><img alt="Alphabet Inc. stock logo" height="28" loading="lazy" src="https://www.marketbeat.com/l ...

# %%
# Initialize lists to hold the Table details
headers = []
data = []

# %%
# Fetching headers using the 'th' tags inside the 'tr' tags
table_headers = soup.thead
for x in table_headers.findAll('tr'):
    for y in x.findAll('th'):
        headers.append(y.text)

# %%
headers
# Out:
# ['Company',
#  'Current Price',
#  'PE Ratio',
#  'Market Cap',
#  'Volume',
#  'Average Volume',
#  'Indicator(s)']

# %%
# Fetching table data using the 'td' tags inside the 'tr' tags
table_body = soup.tbody
for i in table_body.findAll('tr')[1:]:
    td_tags = i.findAll('td')
    td_val = [j.get_text(separator = ',') for j in td_tags]
    data.append(td_val)

# %%
data
# Out:
# [['MSFT,Microsoft',
#   '$257.22,+0.1%',
#   '27.72',
#   '$1.92 trillion',
#   '35.04 million',
#   '31.30 million',
#   'Short Interest ↑'],
#  ['GOOG,Alphabet',
#   '$95.31,-0.6%',
#   '18.93',
#   '$1.23 trillion',
#   '26.17 million',
#   '28.88 million',
#   'Short Interest ↓'],
#  ['GOOGL,Alphabet',
#   '$95.07,-0.6%',
#   '18.88',
#   '$1.23 trillion',
#   '28.40 million',
#   '35.06 million',
#   ''],
#  ['AMZN,Amazon.com',
#   '$91.58,-1.0%',
#   '84.06',
#   '$934.27 billion',
#   '69.69 million',
#   '76.16 million',
#   'Short Interest ↓'],
#  ['UNH,UnitedHealth Group',
#   '$538.36,+0.0%',
#   '26.36',
#   '$503.02 billion',
#   '2.61 million',
#   '3.13 million',
#   ''],
#  ['TSLA,Tesla',
#   '$156.80,-2.6%',
#   '48.45',
#   '$495.14 billion',
#   '139.85 million',
#   '83.06 million',
#   'Analyst Report'],
#  ['JNJ,Johnson & Johnson',
#   '$179.76,+0.3%',
#   '25.04',
#   '$469.98 billion',
#   '9.41 million',
#   '7.32 million',
#   'Analyst Report'],
#  ['NVDA,NVIDIA',
#   '$176.74,-2.2%',
#   '75.21',
#   '$440.08 billion',
#   '49.48 million',
#   '54.96 million',
#   'Analyst Report'],
#  ['XOM,Exxon Mobil',
#   '$106.46,-0.7%',
#   '8.69',
#   '$438.43 billion',
#   '16.94 million',
#   '25.73 million',
#   'Insider Selling,Short Interest ↑,Analyst Revision'],
#  ['V,Visa',
#   '$213.32,+0.1%',
#   '30.52',
#   '$401.79 billion',
#   '7.00 million',
#   '7.60 million',
#   'News Coverage'],
#  ['WMT,Walmart',
#   '$146.67,-0.6%',
#   '45.27',
#   '$395.54 billion',
#   '6.56 million',
#   '8.09 million',
#   ''],
#  ['JPM,JPMorgan Chase & Co.',
#   '$133.41,-0.5%',
#   '11.27',
#   '$391.32 billion',
#   '9.22 million',
#   '13.87 million',
#   'Dividend Announcement,Analyst Report,Short Interest ↓'],
#  ['PG,Procter & Gamble',
#   '$152.84,+0.4%',
#   '26.49',
#   '$364.60 billion',
#   '7.28 million',
#   '7.37 million',
#   ''],
#  ['LLY,Eli Lilly and',
#   '$363.50,+1.3%',
#   '54.58',
#   '$345.39 billion',
#   '5.04 million',
#   '2.92 million',
#   'Dividend Increase,Analyst Report,Short Interest ↑,News Coverage'],
#  ['MA,Mastercard',
#   '$357.51,+0.1%',
#   '35.72',
#   '$343.73 billion',
#   '2.58 million',
#   '3.46 million',
#   ''],
#  ['HD,Home Depot',
#   '$333.43,+0.2%',
#   '20.10',
#   '$341.34 billion',
#   '4.37 million',
#   '4.33 million',
#   'Analyst Report,Short Interest ↑'],
#  ['CVX,Chevron',
#   '$172.33,-0.7%',
#   '9.80',
#   '$333.22 billion',
#   '6.69 million',
#   '11.67 million',
#   'Analyst Downgrade,Options Volume,Analyst Revision'],
#  ['META,Meta Platforms',
#   '$121.59,+1.2%',
#   '11.59',
#   '$322.40 billion',
#   '36.66 million',
#   '35.95 million',
#   'Analyst Report,Short Interest ↓'],
#  ['PFE,Pfizer',
#   '$54.48,+2.7%',
#   '10.48',
#   '$305.81 billion',
#   '35.77 million',
#   '24.53 million',
#   'Dividend Increase,Analyst Report,Options Volume,News Coverage'],
#  ['ABBV,AbbVie',
#   '$164.86,+0.0%',
#   '22.01',
#   '$291.55 billion',
#   '4.32 million',
#   '6.53 million',
#   'Insider Selling,Short Interest ↑'],
#  ['MRK,Merck & Co., Inc.',
#   '$111.55,+1.2%',
#   '18.56',
#   '$282.82 billion',
#   '10.49 million',
#   '10.68 million',
#   ''],
#  ['KO,Coca-Cola',
#   '$63.99',
#   '27.94',
#   '$276.73 billion',
#   '12.64 million',
#   '16.25 million',
#   ''],
#  ['BAC,Bank of America',
#   '$32.28,-1.4%',
#   '10.22',
#   '$258.96 billion',
#   '48.43 million',
#   '47.13 million',
#   'Short Interest ↓'],
#  ['PEP,PepsiCo',
#   '$183.36,-0.3%',
#   '26.23',
#   '$252.62 billion',
#   '5.33 million',
#   '5.14 million',
#   ''],
#  ['AVGO,Broadcom',
#   '$574.44,+0.6%',
#   '21.68',
#   '$232.65 billion',
#   '3.50 million',
#   '2.38 million',
#   'Earnings Report,Dividend Increase,Analyst Report,Short Interest ↓'],
#  ['TMO,Thermo Fisher Scientific',
#   '$567.23,-0.7%',
#   '31.88',
#   '$222.47 billion',
#   '2.04 million',
#   '1.47 million',
#   'Analyst Report'],
#  ['ORCL,Oracle',
#   '$81.82,+1.6%',
#   '38.96',
#   '$220.60 billion',
#   '11.11 million',
#   '8.41 million',
#   'Earnings Report,Dividend Announcement,Analyst Report,News Coverage'],
#  ['COST,Costco Wholesale',
#   '$483.52,-1.0%',
#   '36.55',
#   '$214.62 billion',
#   '2.12 million',
#   '2.51 million',
#   'Insider Selling,Analyst Revision'],
#  ['CSCO,Cisco Systems',
#   '$49.30,-0.7%',
#   '17.80',
#   '$202.57 billion',
#   '18.87 million',
#   '21.37 million',
#   'Dividend Announcement,Analyst Report'],
#  ["MCD,McDonald's",
#   '$274.53,+0.1%',
#   '34.58',
#   '$201.07 billion',
#   '2.51 million',
#   '2.98 million',
#   'Analyst Downgrade'],
#  ['DHR,Danaher',
#   '$274.23,-0.9%',
#   '30.30',
#   '$199.63 billion',
#   '2.56 million',
#   '2.67 million',
#   'Analyst Report'],
#  ['ABT,Abbott Laboratories',
#   '$111.26,-0.2%',
#   '25.12',
#   '$193.99 billion',
#   '5.44 million',
#   '5.59 million',
#   'Dividend Increase,Analyst Report'],
#  ['ACN,Accenture',
#   '$291.45,-1.3%',
#   '27.21',
#   '$183.78 billion',
#   '2.49 million',
#   '2.32 million',
#   'Upcoming Earnings,Analyst Downgrade'],
#  ['TMUS,T-Mobile US',
#   '$142.36,+1.3%',
#   '116.69',
#   '$177.12 billion',
#   '7.38 million',
#   '5.05 million',
#   ''],
#  ['NKE,NIKE',
#   '$111.45,-1.2%',
#   '31.57',
#   '$174.82 billion',
#   '7.12 million',
#   '7.53 million',
#   'Upcoming Earnings,Analyst Report,Analyst Revision'],
#  ['NEE,NextEra Energy',
#   '$87.05,-0.1%',
#   '44.87',
#   '$172.98 billion',
#   '6.03 million',
#   '9.04 million',
#   'Analyst Report,Insider Selling,News Coverage'],
#  ['DIS,Walt Disney',
#   '$94.15,-0.6%',
#   '54.74',
#   '$171.69 billion',
#   '11.29 million',
#   '12.59 million',
#   'Analyst Report,Short Interest ↓'],
#  ['LIN,Linde',
#   '$342.01,-0.1%',
#   '45.24',
#   '$168.46 billion',
#   '1.80 million',
#   '2.13 million',
#   'Short Interest ↓,News Coverage'],
#  ['BMY,Bristol-Myers Squibb',
#   '$77.14,-0.3%',
#   '25.13',
#   '$164.01 billion',
#   '9.11 million',
#   '12.19 million',
#   'Dividend Increase,Analyst Revision,Positive News'],
#  ['WFC,Wells Fargo & Company',
#   '$42.18,-1.0%',
#   '10.96',
#   '$160.73 billion',
#   '21.38 million',
#   '23.53 million',
#   ''],
#  ['TXN,Texas Instruments',
#   '$175.82,-0.9%',
#   '18.43',
#   '$159.57 billion',
#   '4.94 million',
#   '5.94 million',
#   'Analyst Report,Positive News'],
#  ['UPS,United Parcel Service',
#   '$184.31,+0.3%',
#   '14.44',
#   '$159.41 billion',
#   '3.06 million',
#   '3.22 million',
#   ''],
#  ['PM,Philip Morris International',
#   '$102.46,+0.1%',
#   '18.26',
#   '$158.83 billion',
#   '7.46 million',
#   '5.47 million',
#   'Dividend Announcement,Analyst Report,News Coverage'],
#  ['ADBE,Adobe',
#   '$339.92,-0.7%',
#   '33.52',
#   '$158.03 billion',
#   '3.21 million',
#   '3.56 million',
#   'Upcoming Earnings,Analyst Report,Short Interest ↓'],
#  ['VZ,Verizon Communications',
#   '$37.45,-1.1%',
#   '8.12',
#   '$157.28 billion',
#   '23.05 million',
#   '22.97 million',
#   ''],
#  ['MS,Morgan Stanley',
#   '$90.50,-2.4%',
#   '13.13',
#   '$152.95 billion',
#   '7.64 million',
#   '8.93 million',
#   ''],
#  ['CMCSA,Comcast',
#   '$35.35,-3.7%',
#   '30.74',
#   '$152.83 billion',
#   '33.16 million',
#   '24.62 million',
#   'Gap Down'],
#  ['RTX,Raytheon Technologies',
#   '$99.95,+0.1%',
#   '33.32',
#   '$146.93 billion',
#   '4.86 million',
#   '5.32 million',
#   'Analyst Report,Buyback Announcement,News Coverage'],
#  ['AMGN,Amgen',
#   '$271.13,-0.4%',
#   '21.74',
#   '$144.67 billion',
#   '3.77 million',
#   '3.00 million',
#   'Dividend Increase,Analyst Report,Analyst Revision'],
#  ['HON,Honeywell International',
#   '$214.72,-0.1%',
#   '27.49',
#   '$144.36 billion',
#   '2.41 million',
#   '3.17 million',
#   'Options Volume,Analyst Revision,News Coverage'],
#  ['NFLX,Netflix',
#   '$317.83,-0.8%',
#   '28.48',
#   '$141.44 billion',
#   '7.49 million',
#   '10.99 million',
#   'Analyst Report'],
#  ['COP,ConocoPhillips',
#   '$112.87,-0.5%',
#   '8.13',
#   '$140.64 billion',
#   '5.76 million',
#   '7.91 million',
#   'Analyst Report,Short Interest ↓'],
#  ['SCHW,Charles Schwab',
#   '$77.32,-0.6%',
#   '23.50',
#   '$140.40 billion',
#   '8.52 million',
#   '8.08 million',
#   ''],
#  ['QCOM,QUALCOMM',
#   '$121.71,-1.4%',
#   '10.70',
#   '$136.44 billion',
#   '9.39 million',
#   '9.55 million',
#   'Analyst Downgrade'],
#  ['IBM,International Business Machines',
#   '$149.86,-0.5%',
#   '109.39',
#   '$135.49 billion',
#   '4.05 million',
#   '5.04 million',
#   ''],
#  ['CRM,Salesforce',
#   '$134.75,-0.6%',
#   '481.25',
#   '$134.75 billion',
#   '9.44 million',
#   '7.62 million',
#   ''],
#  ['T,AT&T',
#   '$18.90,-1.2%',
#   '7.00',
#   '$134.70 billion',
#   '43.62 million',
#   '51.61 million',
#   'Positive News'],
#  ['UNP,Union Pacific',
#   '$217.58,-0.2%',
#   '19.41',
#   '$133.77 billion',
#   '2.72 million',
#   '3.18 million',
#   'Dividend Announcement'],
#  ['DE,Deere & Company',
#   '$438.44,+0.3%',
#   '18.79',
#   '$132.33 billion',
#   '1.71 million',
#   '1.78 million',
#   'Dividend Increase'],
#  ['CVS,CVS Health',
#   '$100.68,-0.5%',
#   '42.84',
#   '$132.29 billion',
#   '5.06 million',
#   '5.73 million',
#   'Short Interest ↑'],
#  ["LOW,Lowe's Companies",
#   '$212.11,+0.4%',
#   '20.77',
#   '$131.66 billion',
#   '3.63 million',
#   '3.88 million',
#   'Analyst Report,Short Interest ↑,Analyst Revision'],
#  ['LMT,Lockheed Martin',
#   '$485.19,+1.0%',
#   '22.28',
#   '$127.16 billion',
#   '1.06 million',
#   '1.65 million',
#   'Analyst Report,Short Interest ↓,News Coverage'],
#  ['ELV,Elevance Health',
#   '$520.15,+0.2%',
#   '20.41',
#   '$124.84 billion',
#   '864,038',
#   '1.10 million',
#   'Positive News'],
#  ['GS,The Goldman Sachs Group',
#   '$360.38,-2.3%',
#   '9.60',
#   '$122.04 billion',
#   '2.46 million',
#   '2.66 million',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['CAT,Caterpillar',
#   '$234.48,-0.4%',
#   '17.03',
#   '$122.03 billion',
#   '3.40 million',
#   '3.29 million',
#   'Dividend Announcement,Analyst Report'],
#  ['INTU,Intuit',
#   '$418.92,-2.2%',
#   '63.76',
#   '$117.69 billion',
#   '1.62 million',
#   '1.83 million',
#   'Short Interest ↓'],
#  ['SBUX,Starbucks',
#   '$102.19,+0.1%',
#   '36.24',
#   '$117.29 billion',
#   '5.57 million',
#   '8.92 million',
#   'Insider Selling'],
#  ['INTC,Intel',
#   '$28.26,-1.6%',
#   '8.70',
#   '$116.63 billion',
#   '36.67 million',
#   '39.13 million',
#   'Analyst Report'],
#  ['SPGI,S&P Global',
#   '$353.84,-1.1%',
#   '29.59',
#   '$115.28 billion',
#   '1.67 million',
#   '2.16 million',
#   ''],
#  ['AXP,American Express',
#   '$154.11,-2.2%',
#   '15.49',
#   '$115.16 billion',
#   '3.27 million',
#   '3.54 million',
#   'Dividend Announcement,Analyst Report,Short Interest ↓,News Coverage'],
#  ['PLD,Prologis',
#   '$121.58,+0.4%',
#   '22.56',
#   '$112.23 billion',
#   '4.10 million',
#   '3.90 million',
#   'Dividend Announcement,Analyst Report'],
#  ['BA,Boeing',
#   '$188.25,+0.6%',
#   'N/A',
#   '$111.78 billion',
#   '5.67 million',
#   '9.03 million',
#   'Analyst Report,Short Interest ↓'],
#  ['AMD,Advanced Micro Devices',
#   '$68.93,-3.8%',
#   '41.28',
#   '$111.14 billion',
#   '67.05 million',
#   '93.37 million',
#   'Short Interest ↓'],
#  ['GILD,Gilead Sciences',
#   '$88.40,+0.4%',
#   '33.36',
#   '$110.88 billion',
#   '7.54 million',
#   '8.61 million',
#   'Analyst Report,Options Volume'],
#  ['ADP,Automatic Data Processing',
#   '$260.08,-0.8%',
#   '35.97',
#   '$107.89 billion',
#   '1.84 million',
#   '1.81 million',
#   'Analyst Report'],
#  ['BLK,BlackRock',
#   '$711.52,-1.7%',
#   '19.61',
#   '$106.87 billion',
#   '542,297',
#   '861,898',
#   'Analyst Report'],
#  ['MDT,Medtronic',
#   '$78.79,-1.7%',
#   '24.47',
#   '$104.80 billion',
#   '9.24 million',
#   '6.29 million',
#   'Dividend Announcement'],
#  ['AMT,American Tower',
#   '$219.85,-1.6%',
#   '34.90',
#   '$102.36 billion',
#   '1.82 million',
#   '1.96 million',
#   'Dividend Increase,Analyst Report'],
#  ['CI,Cigna',
#   '$334.68,+1.3%',
#   '15.98',
#   '$102.32 billion',
#   '1.20 million',
#   '1.83 million',
#   'Insider Selling'],
#  ['ISRG,Intuitive Surgical',
#   '$280.65,-0.4%',
#   '74.05',
#   '$99.18 billion',
#   '2.86 million',
#   '2.12 million',
#   'Analyst Report,Short Interest ↓'],
#  ['SYK,Stryker',
#   '$253.82,-0.1%',
#   '39.47',
#   '$96.05 billion',
#   '1.19 million',
#   '1.48 million',
#   'Dividend Increase,Analyst Report'],
#  ['AMAT,Applied Materials',
#   '$109.64,-2.0%',
#   '14.74',
#   '$94.32 billion',
#   '6.39 million',
#   '8.08 million',
#   'Dividend Announcement,Short Interest ↓'],
#  ['MDLZ,Mondelez International',
#   '$67.26,-0.5%',
#   '29.89',
#   '$91.85 billion',
#   '7.29 million',
#   '7.52 million',
#   'Dividend Announcement,Analyst Upgrade,Short Interest ↓'],
#  ['TJX,TJX Companies',
#   '$79.29,+0.2%',
#   '27.63',
#   '$91.62 billion',
#   '4.64 million',
#   '6.45 million',
#   ''],
#  ['CB,Chubb',
#   '$216.82,-0.1%',
#   '15.12',
#   '$89.99 billion',
#   '1.64 million',
#   '1.78 million',
#   'Short Interest ↓'],
#  ['C,Citigroup',
#   '$45.98,-1.3%',
#   '6.30',
#   '$89.06 billion',
#   '16.41 million',
#   '22.52 million',
#   ''],
#  ['GE,General Electric',
#   '$81.47,-1.6%',
#   'N/A',
#   '$89.02 billion',
#   '7.46 million',
#   '6.52 million',
#   'Analyst Downgrade'],
#  ['EL,Estée Lauder Companies',
#   '$249.22,+0.4%',
#   '41.61',
#   '$88.92 billion',
#   '1.69 million',
#   '1.67 million',
#   'Analyst Report,Short Interest ↓'],
#  ['ADI,Analog Devices',
#   '$171.68,-2.2%',
#   '32.52',
#   '$87.44 billion',
#   '3.18 million',
#   '3.66 million',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['MMC,Marsh & McLennan Companies',
#   '$172.37,-0.6%',
#   '25.88',
#   '$85.50 billion',
#   '1.79 million',
#   '1.92 million',
#   'Analyst Report,Insider Selling,News Coverage'],
#  ['NOW,ServiceNow',
#   '$418.39,+0.5%',
#   '422.62',
#   '$84.51 billion',
#   '1.45 million',
#   '1.76 million',
#   ''],
#  ['MO,Altria Group',
#   '$47.13,+0.7%',
#   '18.34',
#   '$84.47 billion',
#   '8.35 million',
#   '9.69 million',
#   'Dividend Announcement,Analyst Downgrade,Short Interest ↑'],
#  ['PYPL,PayPal',
#   '$72.63,-1.5%',
#   '36.87',
#   '$82.80 billion',
#   '18.10 million',
#   '17.19 million',
#   'Analyst Report'],
#  ['NOC,Northrop Grumman',
#   '$531.78,+1.2%',
#   '15.11',
#   '$81.85 billion',
#   '547,289',
#   '904,039',
#   ''],
#  ['REGN,Regeneron Pharmaceuticals',
#   '$750.00,+0.3%',
#   '15.81',
#   '$81.68 billion',
#   '558,469',
#   '704,779',
#   'Insider Selling'],
#  ['MRNA,Moderna',
#   '$208.95,+5.8%',
#   '7.56',
#   '$80.27 billion',
#   '21.33 million',
#   '6.17 million',
#   'Analyst Report,News Coverage,High Trading Volume'],
#  ['VRTX,Vertex Pharmaceuticals',
#   '$312.09,+1.6%',
#   '24.61',
#   '$80.11 billion',
#   '1.37 million',
#   '1.59 million',
#   ''],
#  ['DUK,Duke Energy',
#   '$103.30,+0.2%',
#   '20.83',
#   '$79.55 billion',
#   '4.44 million',
#   '2.92 million',
#   'Analyst Report,Short Interest ↓'],
#  ['BKNG,Booking',
#   '$2,006.80,-2.0%',
#   '32.96',
#   '$77.84 billion',
#   '393,343',
#   '418,255',
#   'Analyst Upgrade,Gap Down'],
#  ['SO,Southern',
#   '$71.11,-0.1%',
#   '22.50',
#   '$77.42 billion',
#   '5.00 million',
#   '4.98 million',
#   'Analyst Upgrade'],
#  ['PGR,Progressive',
#   '$126.58,-1.3%',
#   '89.77',
#   '$74.06 billion',
#   '3.36 million',
#   '2.72 million',
#   ''],
#  ['EOG,EOG Resources',
#   '$125.93,0.0%',
#   '9.89',
#   '$73.97 billion',
#   '3.69 million',
#   '4.21 million',
#   'Short Interest ↓,Analyst Revision'],
#  ['APD,Air Products and Chemicals',
#   '$325.12,0.0%',
#   '32.06',
#   '$72.13 billion',
#   '966,834',
#   '1.19 million',
#   'Analyst Downgrade,Short Interest ↑'],
#  ['BDX,Becton, Dickinson and',
#   '$254.04,0.0%',
#   '43.20',
#   '$71.99 billion',
#   '1.74 million',
#   '1.25 million',
#   'Analyst Upgrade'],
#  ['SLB,Schlumberger',
#   '$50.43,-1.2%',
#   '24.25',
#   '$71.51 billion',
#   '10.04 million',
#   '14.36 million',
#   'Short Interest ↓'],
#  ['ZTS,Zoetis',
#   '$151.78,-2.1%',
#   '34.65',
#   '$70.74 billion',
#   '2.16 million',
#   '2.20 million',
#   'Dividend Increase'],
#  ['TGT,Target',
#   '$152.51,+1.1%',
#   '20.89',
#   '$70.19 billion',
#   '3.54 million',
#   '4.79 million',
#   ''],
#  ['MMM,3M',
#   '$126.09,-0.9%',
#   '10.98',
#   '$69.70 billion',
#   '3.05 million',
#   '4.87 million',
#   ''],
#  ['HCA,HCA Healthcare',
#   '$244.70,+0.7%',
#   '13.82',
#   '$69.18 billion',
#   '1.15 million',
#   '1.68 million',
#   'Analyst Report,Short Interest ↑'],
#  ['ITW,Illinois Tool Works',
#   '$224.22,-0.6%',
#   '25.60',
#   '$68.88 billion',
#   '854,458',
#   '1.13 million',
#   'Insider Buying'],
#  ['CSX,CSX',
#   '$32.67,-0.2%',
#   '17.47',
#   '$68.69 billion',
#   '11.61 million',
#   '16.06 million',
#   ''],
#  ['GD,General Dynamics',
#   '$249.02,+0.1%',
#   '20.73',
#   '$68.37 billion',
#   '725,503',
#   '1.27 million',
#   'Dividend Announcement,Options Volume,News Coverage,Positive News'],
#  ['WM,Waste Management',
#   '$166.54,-0.1%',
#   '30.96',
#   '$68.36 billion',
#   '1.54 million',
#   '1.81 million',
#   'Buyback Announcement,News Coverage'],
#  ['BSX,Boston Scientific',
#   '$47.18,0.0%',
#   '112.34',
#   '$67.58 billion',
#   '7.18 million',
#   '7.98 million',
#   'Insider Selling'],
#  ['CL,Colgate-Palmolive',
#   '$79.34,+0.7%',
#   '34.50',
#   '$66.27 billion',
#   '3.66 million',
#   '4.78 million',
#   'Short Interest ↓'],
#  ['HUM,Humana',
#   '$521.51,-0.3%',
#   '23.65',
#   '$66.02 billion',
#   '1.04 million',
#   '1.03 million',
#   'Analyst Upgrade,Insider Selling,News Coverage'],
#  ['EQIX,Equinix',
#   '$703.43,-0.5%',
#   '91.95',
#   '$65.09 billion',
#   '549,623',
#   '474,170',
#   'Analyst Upgrade,Insider Selling,Short Interest ↑,News Coverage'],
#  ['FISV,Fiserv',
#   '$101.91,+0.3%',
#   '31.95',
#   '$64.72 billion',
#   '3.23 million',
#   '3.67 million',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['SHW,Sherwin-Williams',
#   '$248.68,-3.9%',
#   '33.65',
#   '$64.44 billion',
#   '1.73 million',
#   '1.66 million',
#   ''],
#  ['USB,U.S. Bancorp',
#   '$43.29,-2.2%',
#   '10.28',
#   '$64.32 billion',
#   '10.61 million',
#   '8.16 million',
#   'Dividend Announcement,Analyst Upgrade,Insider Selling,News Coverage'],
#  ['ETN,Eaton',
#   '$161.36,-1.4%',
#   '28.21',
#   '$64.17 billion',
#   '1.60 million',
#   '1.93 million',
#   'Analyst Downgrade'],
#  ['LRCX,Lam Research',
#   '$468.24,-1.6%',
#   '13.43',
#   '$63.86 billion',
#   '1.20 million',
#   '1.58 million',
#   'Analyst Upgrade,Short Interest ↓'],
#  ['AON,AON',
#   '$306.14,-1.2%',
#   '23.77',
#   '$63.33 billion',
#   '1.14 million',
#   '1.00 million',
#   'Analyst Report,Short Interest ↑'],
#  ['CME,CME Group',
#   '$174.92,-1.8%',
#   '23.80',
#   '$62.92 billion',
#   '2.29 million',
#   '1.71 million',
#   'Dividend Increase,Analyst Report'],
#  ['PNC,The PNC Financial Services Group',
#   '$149.62,-2.9%',
#   '11.28',
#   '$60.34 billion',
#   '3.19 million',
#   '2.14 million',
#   ''],
#  ['ATVI,Activision Blizzard',
#   '$77.04,+0.4%',
#   '36.17',
#   '$60.29 billion',
#   '4.81 million',
#   '7.57 million',
#   'Short Interest ↓'],
#  ['NSC,Norfolk Southern',
#   '$258.42,+0.2%',
#   '19.00',
#   '$59.83 billion',
#   '1.45 million',
#   '1.34 million',
#   'Insider Selling'],
#  ['MU,Micron Technology',
#   '$54.59,-1.2%',
#   '7.06',
#   '$59.55 billion',
#   '11.11 million',
#   '19.35 million',
#   'Upcoming Earnings,Analyst Downgrade'],
#  ['CCI,Crown Castle',
#   '$137.48,-4.1%',
#   '36.96',
#   '$59.54 billion',
#   '3.71 million',
#   '1.91 million',
#   'Short Interest ↓,Positive News'],
#  ['ICE,Intercontinental Exchange',
#   '$103.93,-1.9%',
#   '23.04',
#   '$58.05 billion',
#   '2.21 million',
#   '2.92 million',
#   ''],
#  ['OXY,Occidental Petroleum',
#   '$63.68,-0.9%',
#   '5.30',
#   '$57.88 billion',
#   '13.22 million',
#   '26.17 million',
#   'Analyst Report'],
#  ['EMR,Emerson Electric',
#   '$97.72,-0.4%',
#   '18.06',
#   '$57.79 billion',
#   '4.01 million',
#   '3.15 million',
#   ''],
#  ['KLAC,KLA',
#   '$406.21,-0.7%',
#   '18.35',
#   '$57.57 billion',
#   '1.55 million',
#   '1.56 million',
#   'Analyst Downgrade,Insider Selling,Short Interest ↓'],
#  ['MET,MetLife',
#   '$72.84,-0.5%',
#   '27.38',
#   '$57.15 billion',
#   '3.07 million',
#   '4.42 million',
#   'Insider Selling,Short Interest ↓,Analyst Revision'],
#  ['FCX,Freeport-McMoRan',
#   '$39.43,+0.4%',
#   '14.99',
#   '$56.36 billion',
#   '11.09 million',
#   '18.24 million',
#   ''],
#  ['TFC,Truist Financial',
#   '$42.22,-2.2%',
#   '9.68',
#   '$56.02 billion',
#   '9.18 million',
#   '6.80 million',
#   'Analyst Report,Short Interest ↓,Positive News'],
#  ['DG,Dollar General',
#   '$247.48,+1.7%',
#   '24.05',
#   '$55.33 billion',
#   '1.87 million',
#   '1.95 million',
#   ''],
#  ["MCO,Moody's",
#   '$297.62,-1.3%',
#   '35.52',
#   '$54.52 billion',
#   '1.03 million',
#   '894,657',
#   ''],
#  ['GM,General Motors',
#   '$38.36,-1.1%',
#   '6.50',
#   '$54.50 billion',
#   '11.89 million',
#   '16.66 million',
#   'Short Interest ↓'],
#  ['PXD,Pioneer Natural Resources',
#   '$225.12,+0.1%',
#   '8.03',
#   '$54.47 billion',
#   '1.89 million',
#   '2.53 million',
#   'Short Interest ↑,Analyst Revision'],
#  ['F,Ford Motor',
#   '$13.48,-0.7%',
#   '6.13',
#   '$54.20 billion',
#   '50.60 million',
#   '73.12 million',
#   'Short Interest ↓'],
#  ['MNST,Monster Beverage',
#   '$101.90,+1.5%',
#   '45.09',
#   '$53.17 billion',
#   '2.76 million',
#   '2.77 million',
#   'Short Interest ↑'],
#  ['KDP,Keurig Dr Pepper',
#   '$37.34,-0.8%',
#   '29.17',
#   '$52.88 billion',
#   '9.52 million',
#   '8.21 million',
#   'Options Volume'],
#  ['MCK,McKesson',
#   '$372.31,+0.3%',
#   '26.27',
#   '$52.79 billion',
#   '1.56 million',
#   '1.11 million',
#   'Insider Selling,News Coverage'],
#  ['PSA,Public Storage',
#   '$300.18,-0.6%',
#   '12.20',
#   '$52.72 billion',
#   '1.25 million',
#   '776,091',
#   'Insider Buying'],
#  ['MPC,Marathon Petroleum',
#   '$110.94,-0.2%',
#   '4.87',
#   '$51.99 billion',
#   '4.23 million',
#   '5.66 million',
#   'Analyst Downgrade,Short Interest ↑'],
#  ['GIS,General Mills',
#   '$87.33,+0.4%',
#   '18.39',
#   '$51.83 billion',
#   '3.98 million',
#   '3.81 million',
#   'Upcoming Earnings,Options Volume'],
#  ['SRE,Sempra',
#   '$163.75,-0.6%',
#   '22.97',
#   '$51.47 billion',
#   '1.02 million',
#   '1.52 million',
#   'Analyst Report'],
#  ['CHTR,Charter Communications',
#   '$328.34,-16.4%',
#   '10.26',
#   '$51.11 billion',
#   '5.66 million',
#   '1.47 million',
#   'Analyst Report,News Coverage,Gap Down,High Trading Volume'],
#  ['ADM,Archer-Daniels-Midland',
#   '$92.80,-0.5%',
#   '12.80',
#   '$50.98 billion',
#   '2.75 million',
#   '3.29 million',
#   'Analyst Downgrade,Insider Selling,News Coverage'],
#  ["ORLY,O'Reilly Automotive",
#   '$814.50,-0.5%',
#   '24.86',
#   '$50.97 billion',
#   '506,115',
#   '544,045',
#   ''],
#  ['SNPS,Synopsys',
#   '$332.03,-1.8%',
#   '52.70',
#   '$50.77 billion',
#   '1.48 million',
#   '1.01 million',
#   ''],
#  ['AEP,American Electric Power',
#   '$98.49,-0.1%',
#   '20.39',
#   '$50.61 billion',
#   '3.03 million',
#   '3.02 million',
#   'Analyst Report'],
#  ['MAR,Marriott International',
#   '$159.33,-2.3%',
#   '24.29',
#   '$50.43 billion',
#   '2.45 million',
#   '2.25 million',
#   'Analyst Downgrade,Short Interest ↑'],
#  ['D,Dominion Energy',
#   '$59.27,-1.2%',
#   '21.24',
#   '$49.39 billion',
#   '7.81 million',
#   '3.91 million',
#   'Options Volume'],
#  ['KHC,Kraft Heinz',
#   '$40.16,+0.5%',
#   '40.98',
#   '$49.19 billion',
#   '6.73 million',
#   '7.75 million',
#   ''],
#  ['APH,Amphenol',
#   '$81.72,-0.3%',
#   '27.42',
#   '$48.63 billion',
#   '3.32 million',
#   '2.37 million',
#   'Analyst Report'],
#  ['HSY,Hershey',
#   '$236.01,-0.1%',
#   '30.81',
#   '$48.40 billion',
#   '675,527',
#   '1.02 million',
#   'Insider Selling,Short Interest ↑'],
#  ['PSX,Phillips 66',
#   '$101.28,-0.8%',
#   '4.63',
#   '$47.87 billion',
#   '2.47 million',
#   '3.90 million',
#   'Short Interest ↑'],
#  ['CNC,Centene',
#   '$83.00,-0.3%',
#   '24.20',
#   '$47.00 billion',
#   '4.21 million',
#   '3.18 million',
#   'Analyst Downgrade,News Coverage'],
#  ['KMB,Kimberly-Clark',
#   '$139.10,+0.3%',
#   '26.34',
#   '$46.95 billion',
#   '1.53 million',
#   '1.76 million',
#   'Options Volume'],
#  ['DXCM,DexCom',
#   '$121.49,+1.6%',
#   '223.95',
#   '$46.93 billion',
#   '3.24 million',
#   '3.20 million',
#   'Analyst Report'],
#  ['EW,Edwards Lifesciences',
#   '$75.82,-0.2%',
#   '32.68',
#   '$46.88 billion',
#   '5.03 million',
#   '3.29 million',
#   'Analyst Report,Insider Selling,Analyst Revision'],
#  ['CTAS,Cintas',
#   '$459.28,-0.7%',
#   '38.50',
#   '$46.64 billion',
#   '279,534',
#   '475,026',
#   'Short Interest ↓'],
#  ['AIG,American International Group',
#   '$62.66,-0.9%',
#   '3.73',
#   '$46.56 billion',
#   '5.74 million',
#   '4.94 million',
#   'Analyst Report,News Coverage,Positive News'],
#  ['ROP,Roper Technologies',
#   '$438.79,-1.1%',
#   '16.12',
#   '$46.53 billion',
#   '365,925',
#   '555,129',
#   ''],
#  ['FDX,FedEx',
#   '$178.07,+0.7%',
#   '13.15',
#   '$46.34 billion',
#   '1.57 million',
#   '2.79 million',
#   'Upcoming Earnings,Analyst Report'],
#  ['VLO,Valero Energy',
#   '$119.73,-0.7%',
#   '5.11',
#   '$46.16 billion',
#   '3.59 million',
#   '4.61 million',
#   'Short Interest ↑'],
#  ['A,Agilent Technologies',
#   '$154.81,-1.8%',
#   '37.12',
#   '$45.83 billion',
#   '1.33 million',
#   '1.73 million',
#   ''],
#  ['JCI,Johnson Controls International',
#   '$66.55,0.0%',
#   '30.11',
#   '$45.70 billion',
#   '4.70 million',
#   '4.32 million',
#   'Dividend Announcement,Analyst Downgrade,Insider Selling,Short Interest ↓'],
#  ['CDNS,Cadence Design Systems',
#   '$165.47,-1.6%',
#   '58.26',
#   '$45.39 billion',
#   '1.45 million',
#   '1.75 million',
#   'Analyst Report,News Coverage,Positive News'],
#  ['ENPH,Enphase Energy',
#   '$332.80,+2.1%',
#   '160.00',
#   '$45.24 billion',
#   '2.67 million',
#   '3.36 million',
#   'Insider Selling,Short Interest ↑'],
#  ['AZO,AutoZone',
#   '$2,360.47,-1.4%',
#   '19.79',
#   '$44.80 billion',
#   '158,891',
#   '173,643',
#   'Analyst Downgrade,Short Interest ↑'],
#  ['NXPI,NXP Semiconductors',
#   '$171.57,-1.1%',
#   '17.09',
#   '$44.46 billion',
#   '1.96 million',
#   '2.62 million',
#   'Analyst Report'],
#  ['MSI,Motorola Solutions',
#   '$265.83,-0.2%',
#   '39.09',
#   '$44.45 billion',
#   '947,799',
#   '830,606',
#   ''],
#  ['PAYX,Paychex',
#   '$122.67,-0.5%',
#   '30.90',
#   '$44.21 billion',
#   '1.50 million',
#   '1.77 million',
#   ''],
#  ['STZ,Constellation Brands',
#   '$239.55,-0.5%',
#   '772.77',
#   '$44.19 billion',
#   '1.23 million',
#   '1.02 million',
#   'Analyst Upgrade,Short Interest ↓,News Coverage'],
#  ['CTVA,Corteva',
#   '$61.70,-1.5%',
#   '32.99',
#   '$44.08 billion',
#   '2.80 million',
#   '3.65 million',
#   'Short Interest ↓'],
#  ['AFL,Aflac',
#   '$70.39,-0.4%',
#   '8.98',
#   '$43.77 billion',
#   '2.56 million',
#   '2.80 million',
#   ''],
#  ['TRV,Travelers Companies',
#   '$186.64,-0.2%',
#   '13.64',
#   '$43.74 billion',
#   '950,274',
#   '1.36 million',
#   ''],
#  ['ADSK,Autodesk',
#   '$200.06,-1.5%',
#   '70.69',
#   '$43.17 billion',
#   '1.36 million',
#   '1.71 million',
#   ''],
#  ['FIS,Fidelity National Information Services',
#   '$72.41,-0.8%',
#   '47.33',
#   '$42.97 billion',
#   '4.33 million',
#   '4.64 million',
#   'Short Interest ↓,Analyst Revision'],
#  ['RSG,Republic Services',
#   '$135.93,-0.3%',
#   '29.68',
#   '$42.95 billion',
#   '1.01 million',
#   '1.24 million',
#   ''],
#  ['ECL,Ecolab',
#   '$150.44,-1.5%',
#   '38.28',
#   '$42.85 billion',
#   '1.14 million',
#   '1.38 million',
#   'Dividend Increase,Short Interest ↓'],
#  ['CMG,Chipotle Mexican Grill',
#   '$1,538.29,-0.6%',
#   '53.54',
#   '$42.64 billion',
#   '221,697',
#   '287,835',
#   ''],
#  ['EXC,Exelon',
#   '$42.82,+0.7%',
#   '19.82',
#   '$42.55 billion',
#   '7.23 million',
#   '8.29 million',
#   'Analyst Report,Short Interest ↑'],
#  ['FTNT,Fortinet',
#   '$54.27,-0.8%',
#   '59.90',
#   '$42.40 billion',
#   '3.53 million',
#   '6.24 million',
#   'Short Interest ↑'],
#  ['HES,Hess',
#   '$136.16,-0.7%',
#   '22.66',
#   '$41.98 billion',
#   '1.22 million',
#   '2.39 million',
#   'Dividend Announcement,Short Interest ↑'],
#  ['MCHP,Microchip Technology',
#   '$76.11,-1.7%',
#   '23.28',
#   '$41.86 billion',
#   '3.68 million',
#   '4.99 million',
#   'Short Interest ↑,News Coverage'],
#  ['SYY,Sysco',
#   '$82.14,-0.4%',
#   '29.13',
#   '$41.63 billion',
#   '1.70 million',
#   '2.42 million',
#   'Analyst Downgrade'],
#  ['BIIB,Biogen',
#   '$289.05,-0.8%',
#   '14.72',
#   '$41.62 billion',
#   '898,924',
#   '1.30 million',
#   'Insider Selling'],
#  ['LHX,L3Harris Technologies',
#   '$218.04,+0.9%',
#   '37.85',
#   '$41.52 billion',
#   '757,935',
#   '1.22 million',
#   'Analyst Report,Short Interest ↓'],
#  ['WMB,Williams Companies',
#   '$33.72,-0.2%',
#   '20.56',
#   '$41.08 billion',
#   '4.65 million',
#   '8.24 million',
#   ''],
#  ['AJG,Arthur J. Gallagher & Co.',
#   '$193.11,-0.4%',
#   '38.01',
#   '$40.72 billion',
#   '738,103',
#   '940,766',
#   'Analyst Report,Short Interest ↓,News Coverage'],
#  ['KMI,Kinder Morgan',
#   '$18.11,-0.5%',
#   '16.46',
#   '$40.71 billion',
#   '13.70 million',
#   '17.41 million',
#   ''],
#  ['TT,Trane Technologies',
#   '$176.54,+0.2%',
#   '25.51',
#   '$40.66 billion',
#   '1.08 million',
#   '1.46 million',
#   'Analyst Downgrade,News Coverage'],
#  ['O,Realty Income',
#   '$64.66,-0.5%',
#   '60.43',
#   '$40.55 billion',
#   '4.72 million',
#   '3.96 million',
#   'Dividend Announcement,Analyst Upgrade,Short Interest ↓'],
#  ['DVN,Devon Energy',
#   '$61.92,-0.1%',
#   '6.50',
#   '$40.48 billion',
#   '9.01 million',
#   '12.23 million',
#   'Short Interest ↓'],
#  ['ROST,Ross Stores',
#   '$117.42,-0.1%',
#   '28.50',
#   '$40.44 billion',
#   '2.17 million',
#   '3.10 million',
#   'Analyst Report'],
#  ['ANET,Arista Networks',
#   '$130.99,-1.5%',
#   '35.69',
#   '$40.03 billion',
#   '2.14 million',
#   '2.08 million',
#   'Analyst Report,Insider Selling'],
#  ['MSCI,MSCI',
#   '$498.48,-2.6%',
#   '48.07',
#   '$39.86 billion',
#   '541,198',
#   '515,058',
#   'Analyst Report,Short Interest ↑,News Coverage'],
#  ['IQV,IQVIA',
#   '$214.21,-1.2%',
#   '34.89',
#   '$39.79 billion',
#   '1.28 million',
#   '1.09 million',
#   'Short Interest ↓,News Coverage'],
#  ['TEL,TE Connectivity',
#   '$124.25,-1.0%',
#   '16.63',
#   '$39.42 billion',
#   '1.69 million',
#   '1.63 million',
#   'Analyst Report,Insider Selling,News Coverage'],
#  ['SPG,Simon Property Group',
#   '$119.71,-0.4%',
#   '19.99',
#   '$39.14 billion',
#   '1.77 million',
#   '2.06 million',
#   'Analyst Report,Short Interest ↑'],
#  ['XEL,Xcel Energy',
#   '$71.25,-0.5%',
#   '23.28',
#   '$38.99 billion',
#   '2.50 million',
#   '3.26 million',
#   'Dividend Announcement,Analyst Report'],
#  ['PH,Parker-Hannifin',
#   '$296.99,-0.4%',
#   '30.90',
#   '$38.14 billion',
#   '686,462',
#   '807,002',
#   ''],
#  ['PRU,Prudential Financial',
#   '$102.07,-1.1%',
#   '141.76',
#   '$37.97 billion',
#   '1.48 million',
#   '1.91 million',
#   ''],
#  ['NUE,Nucor',
#   '$147.93,-1.0%',
#   '4.65',
#   '$37.95 billion',
#   '1.67 million',
#   '2.65 million',
#   'Dividend Increase,Options Volume,News Coverage'],
#  ['NEM,Newmont',
#   '$47.11,-0.1%',
#   '37.39',
#   '$37.39 billion',
#   '7.52 million',
#   '8.25 million',
#   'Short Interest ↓'],
#  ['LVS,Las Vegas Sands',
#   '$48.75,+0.2%',
#   '19.90',
#   '$37.25 billion',
#   '4.55 million',
#   '7.31 million',
#   ''],
#  ['YUM,Yum! Brands',
#   '$131.22,+0.8%',
#   '29.96',
#   '$36.96 billion',
#   '1.58 million',
#   '1.81 million',
#   'Analyst Report,Short Interest ↑,News Coverage'],
#  ['COF,Capital One Financial',
#   '$96.60,-2.3%',
#   '4.78',
#   '$36.87 billion',
#   '3.19 million',
#   '2.77 million',
#   'Short Interest ↑'],
#  ['HLT,Hilton Worldwide',
#   '$136.05,-1.5%',
#   '35.34',
#   '$36.80 billion',
#   '2.02 million',
#   '2.24 million',
#   'Analyst Downgrade,Short Interest ↓,News Coverage'],
#  ['CARR,Carrier Global',
#   '$43.80,-1.2%',
#   '10.58',
#   '$36.63 billion',
#   '3.99 million',
#   '4.72 million',
#   'Dividend Increase,Short Interest ↓'],
#  ['BK,Bank of New York Mellon',
#   '$44.94,-1.7%',
#   '13.66',
#   '$36.32 billion',
#   '4.09 million',
#   '4.91 million',
#   'Short Interest ↓,News Coverage'],
#  ['DOW,DOW',
#   '$51.36,-0.4%',
#   '6.66',
#   '$36.15 billion',
#   '4.03 million',
#   '5.83 million',
#   'News Coverage'],
#  ['PCAR,PACCAR',
#   '$102.76,+0.5%',
#   '13.76',
#   '$35.74 billion',
#   '2.37 million',
#   '1.90 million',
#   'Analyst Report,Stock Split,News Coverage,Gap Up'],
#  ['IDXX,IDEXX Laboratories',
#   '$430.03,-1.2%',
#   '54.64',
#   '$35.61 billion',
#   '559,376',
#   '572,987',
#   ''],
#  ['WBA,Walgreens Boots Alliance',
#   '$40.63,-1.0%',
#   '8.13',
#   '$35.04 billion',
#   '4.41 million',
#   '7.03 million',
#   'Analyst Report'],
#  ['ED,Consolidated Edison',
#   '$98.44,-0.1%',
#   '20.64',
#   '$34.93 billion',
#   '1.85 million',
#   '1.86 million',
#   'Analyst Report'],
#  ['DD,DuPont de Nemours',
#   '$69.64,-1.7%',
#   '19.24',
#   '$34.60 billion',
#   '2.66 million',
#   '3.03 million',
#   ''],
#  ['ALL,Allstate',
#   '$129.90,-0.3%',
#   'N/A',
#   '$34.45 billion',
#   '1.51 million',
#   '1.99 million',
#   'Short Interest ↑'],
#  ['EA,Electronic Arts',
#   '$124.66,-0.8%',
#   '38.83',
#   '$34.42 billion',
#   '1.47 million',
#   '2.21 million',
#   'Short Interest ↓'],
#  ['AMP,Ameriprise Financial',
#   '$321.93,-0.9%',
#   '13.42',
#   '$34.26 billion',
#   '533,373',
#   '624,827',
#   'Short Interest ↓'],
#  ['ODFL,Old Dominion Freight Line',
#   '$309.40,+1.6%',
#   '26.51',
#   '$34.18 billion',
#   '1.18 million',
#   '955,026',
#   ''],
#  ['TDG,TransDigm Group',
#   '$628.01,+0.2%',
#   '46.73',
#   '$34.15 billion',
#   '432,694',
#   '304,263',
#   'Analyst Report'],
#  ['CMI,Cummins',
#   '$241.84,-0.4%',
#   '18.03',
#   '$34.10 billion',
#   '940,356',
#   '1.02 million',
#   'Analyst Report'],
#  ['ABC,AmerisourceBergen',
#   '$165.27,+0.1%',
#   '20.56',
#   '$33.99 billion',
#   '2.00 million',
#   '1.31 million',
#   'Insider Selling,Short Interest ↓'],
#  ['OTIS,Otis Worldwide',
#   '$80.25,-0.9%',
#   '27.58',
#   '$33.43 billion',
#   '2.96 million',
#   '2.44 million',
#   'Short Interest ↑'],
#  ['HAL,Halliburton',
#   '$36.55,-1.2%',
#   '18.94',
#   '$33.19 billion',
#   '9.79 million',
#   '11.72 million',
#   ''],
#  ['BF.B,Brown-Forman',
#   '$69.19,+0.5%',
#   '37.60',
#   '$33.15 billion',
#   '1.22 million',
#   '1.04 million',
#   'Analyst Revision'],
#  ['ILMN,Illumina',
#   '$209.98,-0.4%',
#   'N/A',
#   '$33.03 billion',
#   '1.17 million',
#   '1.32 million',
#   'Analyst Downgrade'],
#  ['VICI,VICI Properties',
#   '$34.19,-0.6%',
#   '31.95',
#   '$32.93 billion',
#   '5.66 million',
#   '9.37 million',
#   'Dividend Announcement'],
#  ['MTD,Mettler-Toledo International',
#   '$1,474.76,-2.5%',
#   '40.36',
#   '$32.88 billion',
#   '125,480',
#   '120,923',
#   ''],
#  ['DLTR,Dollar Tree',
#   '$146.50,+1.3%',
#   '20.40',
#   '$32.81 billion',
#   '1.79 million',
#   '2.48 million',
#   'Short Interest ↑'],
#  ['KEYS,Keysight Technologies',
#   '$182.98,-1.2%',
#   '29.61',
#   '$32.72 billion',
#   '841,015',
#   '1.02 million',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['AME,AMETEK',
#   '$141.75,-1.2%',
#   '28.99',
#   '$32.55 billion',
#   '843,524',
#   '1.05 million',
#   'Short Interest ↓'],
#  ['RMD,ResMed',
#   '$220.86,-1.3%',
#   '41.28',
#   '$32.35 billion',
#   '617,048',
#   '552,877',
#   ''],
#  ['KR,Kroger',
#   '$44.76,-1.5%',
#   '13.99',
#   '$32.04 billion',
#   '5.70 million',
#   '6.63 million',
#   'Analyst Upgrade'],
#  ['WELL,Welltower',
#   '$67.35,+1.6%',
#   '146.42',
#   '$31.82 billion',
#   '3.21 million',
#   '2.56 million',
#   ''],
#  ['SBAC,SBA Communications',
#   '$294.39,-2.4%',
#   '79.35',
#   '$31.78 billion',
#   '476,749',
#   '690,610',
#   'Analyst Report,Positive News'],
#  ['NDAQ,Nasdaq',
#   '$63.59,-2.2%',
#   '27.85',
#   '$31.24 billion',
#   '3.96 million',
#   '2.53 million',
#   ''],
#  ['PPG,PPG Industries',
#   '$132.77,-1.0%',
#   '29.37',
#   '$31.20 billion',
#   '870,738',
#   '1.46 million',
#   'Short Interest ↑'],
#  ['ROK,Rockwell Automation',
#   '$269.17,-0.9%',
#   '33.77',
#   '$30.91 billion',
#   '1.01 million',
#   '836,038',
#   'Analyst Downgrade,Insider Selling'],
#  ['WEC,WEC Energy Group',
#   '$97.72,-1.3%',
#   '22.36',
#   '$30.82 billion',
#   '1.96 million',
#   '1.47 million',
#   'Dividend Increase,Analyst Report,News Coverage'],
#  ['PEG,Public Service Enterprise Group',
#   '$61.18,+0.1%',
#   '44.99',
#   '$30.53 billion',
#   '1.96 million',
#   '2.79 million',
#   ''],
#  ['DHI,D.R. Horton',
#   '$87.40,+0.1%',
#   '5.28',
#   '$30.10 billion',
#   '2.48 million',
#   '3.48 million',
#   'Analyst Report'],
#  ['DLR,Digital Realty Trust',
#   '$104.64,-4.7%',
#   '21.49',
#   '$30.09 billion',
#   '4.56 million',
#   '1.74 million',
#   'Analyst Downgrade,News Coverage,Gap Down,High Trading Volume'],
#  ['CTSH,Cognizant Technology Solutions',
#   '$58.23,-1.6%',
#   '12.94',
#   '$29.93 billion',
#   '4.44 million',
#   '3.34 million',
#   'Options Volume'],
#  ['ES,Eversource Energy',
#   '$85.85,-0.1%',
#   '21.41',
#   '$29.90 billion',
#   '1.32 million',
#   '1.69 million',
#   'Analyst Report'],
#  ['OKE,ONEOK',
#   '$66.59,-0.6%',
#   '18.50',
#   '$29.76 billion',
#   '2.35 million',
#   '2.72 million',
#   'Short Interest ↑'],
#  ['CPRT,Copart',
#   '$62.47,-0.4%',
#   '27.95',
#   '$29.74 billion',
#   '2.25 million',
#   '2.35 million',
#   ''],
#  ['STT,State Street',
#   '$79.89,-1.8%',
#   '11.32',
#   '$29.31 billion',
#   '3.84 million',
#   '2.51 million',
#   'Analyst Report'],
#  ['ON,onsemi',
#   '$67.59,-5.5%',
#   '17.51',
#   '$29.23 billion',
#   '10.91 million',
#   '7.61 million',
#   'Analyst Report'],
#  ['BKR,Baker Hughes',
#   '$28.98,-1.0%',
#   'N/A',
#   '$29.23 billion',
#   '7.49 million',
#   '10.10 million',
#   ''],
#  ['GWW,W.W. Grainger',
#   '$576.02,-1.5%',
#   '20.59',
#   '$29.11 billion',
#   '527,869',
#   '311,849',
#   'Positive News'],
#  ['ALB,Albemarle',
#   '$247.86,-5.4%',
#   '18.79',
#   '$29.04 billion',
#   '1.97 million',
#   '1.31 million',
#   'Short Interest ↑'],
#  ['AWK,American Water Works',
#   '$158.35,-0.5%',
#   '21.84',
#   '$28.79 billion',
#   '670,319',
#   '902,449',
#   'Dividend Announcement,Analyst Report,Short Interest ↑'],
#  ['VRSK,Verisk Analytics',
#   '$182.97,-0.8%',
#   '28.41',
#   '$28.61 billion',
#   '764,856',
#   '1.01 million',
#   ''],
#  ['GLW,Corning',
#   '$33.73,-0.8%',
#   '15.76',
#   '$28.53 billion',
#   '4.00 million',
#   '4.90 million',
#   'Analyst Report,Short Interest ↑'],
#  ['FAST,Fastenal',
#   '$49.58,-1.1%',
#   '26.51',
#   '$28.40 billion',
#   '4.61 million',
#   '3.45 million',
#   ''],
#  ['DFS,Discover Financial Services',
#   '$103.45,-2.9%',
#   '6.74',
#   '$28.27 billion',
#   '1.98 million',
#   '1.81 million',
#   'Analyst Downgrade,Short Interest ↓,News Coverage'],
#  ['HPQ,HP',
#   '$28.36,-1.8%',
#   '9.42',
#   '$27.85 billion',
#   '6.61 million',
#   '11.00 million',
#   'Insider Selling'],
#  ['IT,Gartner',
#   '$347.25,-1.3%',
#   '37.42',
#   '$27.44 billion',
#   '319,731',
#   '510,235',
#   ''],
#  ['LYB,LyondellBasell Industries',
#   '$83.68,-0.5%',
#   '6.48',
#   '$27.25 billion',
#   '1.43 million',
#   '2.32 million',
#   'Short Interest ↑'],
#  ['IFF,International Flavors & Fragrances',
#   '$105.63,-1.5%',
#   'N/A',
#   '$26.93 billion',
#   '3.31 million',
#   '1.54 million',
#   'Analyst Report,Analyst Revision,High Trading Volume'],
#  ['ZBH,Zimmer Biomet',
#   '$128.24,-0.1%',
#   '97.15',
#   '$26.91 billion',
#   '1.47 million',
#   '1.40 million',
#   'Analyst Report,Short Interest ↑'],
#  ['WBD,Warner Bros. Discovery',
#   '$10.98,+0.8%',
#   'N/A',
#   '$26.66 billion',
#   '35.11 million',
#   '24.25 million',
#   'News Coverage'],
#  ['WTW,Willis Towers Watson Public',
#   '$245.63,-0.6%',
#   '10.72',
#   '$26.59 billion',
#   '560,875',
#   '780,627',
#   'Dividend Announcement,Analyst Upgrade,Short Interest ↑,News Coverage'],
#  ['TROW,T. Rowe Price Group',
#   '$118.58,-4.0%',
#   '13.61',
#   '$26.50 billion',
#   '3.17 million',
#   '1.78 million',
#   'Insider Selling,News Coverage'],
#  ['LEN,Lennar',
#   '$90.82,+0.3%',
#   '6.01',
#   '$26.44 billion',
#   '3.43 million',
#   '2.68 million',
#   'Upcoming Earnings,Analyst Upgrade,Options Volume,News Coverage'],
#  ['GPN,Global Payments',
#   '$97.73,-1.7%',
#   '444.25',
#   '$26.43 billion',
#   '3.71 million',
#   '2.11 million',
#   'Analyst Report,Insider Buying,News Coverage'],
#  ['BAX,Baxter International',
#   '$52.30,-1.6%',
#   'N/A',
#   '$26.37 billion',
#   '6.95 million',
#   '3.46 million',
#   'Analyst Downgrade,Short Interest ↓,High Trading Volume'],
#  ['APTV,Aptiv',
#   '$96.60,-1.0%',
#   '84.00',
#   '$26.17 billion',
#   '1.71 million',
#   '2.05 million',
#   ''],
#  ['CDW,CDW',
#   '$192.03,-0.5%',
#   '25.23',
#   '$26.00 billion',
#   '654,344',
#   '788,008',
#   'Short Interest ↑'],
#  ['EIX,Edison International',
#   '$67.65,-0.3%',
#   '35.79',
#   '$25.83 billion',
#   '1.65 million',
#   '1.92 million',
#   'Dividend Increase,Analyst Report,Positive News'],
#  ['URI,United Rentals',
#   '$368.14,+0.3%',
#   '13.52',
#   '$25.52 billion',
#   '941,000',
#   '743,696',
#   'Analyst Report'],
#  ['HRL,Hormel Foods',
#   '$46.51,-0.3%',
#   '25.42',
#   '$25.41 billion',
#   '1.54 million',
#   '1.81 million',
#   'Insider Selling,Short Interest ↑'],
#  ['GPC,Genuine Parts',
#   '$179.08,+0.6%',
#   '21.50',
#   '$25.28 billion',
#   '826,210',
#   '830,452',
#   'Analyst Downgrade'],
#  ['K,Kellogg',
#   '$73.72,+0.1%',
#   '16.99',
#   '$25.16 billion',
#   '1.57 million',
#   '2.51 million',
#   'Insider Selling,Short Interest ↑'],
#  ['ARE,Alexandria Real Estate Equities',
#   '$152.97,+0.2%',
#   '46.50',
#   '$25.10 billion',
#   '800,060',
#   '980,781',
#   'Insider Selling,Short Interest ↓'],
#  ['CBRE,CBRE Group',
#   '$79.41,-0.6%',
#   '13.10',
#   '$25.09 billion',
#   '2.01 million',
#   '1.82 million',
#   'Short Interest ↑'],
#  ['EFX,Equifax',
#   '$202.95,-1.9%',
#   '35.23',
#   '$24.85 billion',
#   '930,314',
#   '978,769',
#   'Short Interest ↑'],
#  ['MTB,M&T Bank',
#   '$143.79,-1.6%',
#   '13.57',
#   '$24.82 billion',
#   '1.49 million',
#   '1.37 million',
#   'Analyst Report,Short Interest ↑,News Coverage'],
#  ['VMC,Vulcan Materials',
#   '$184.60,-0.7%',
#   '41.48',
#   '$24.53 billion',
#   '831,478',
#   '776,143',
#   'Analyst Report'],
#  ['FE,FirstEnergy',
#   '$42.34,+0.2%',
#   '19.33',
#   '$24.21 billion',
#   '3.21 million',
#   '3.96 million',
#   'Dividend Announcement,Analyst Report'],
#  ['EQR,Equity Residential',
#   '$63.93,-0.4%',
#   '21.03',
#   '$24.16 billion',
#   '1.71 million',
#   '1.72 million',
#   'Insider Selling'],
#  ['ETR,Entergy',
#   '$118.44,+0.1%',
#   '19.23',
#   '$24.10 billion',
#   '1.56 million',
#   '1.17 million',
#   'Analyst Report,Short Interest ↓'],
#  ['FANG,Diamondback Energy',
#   '$136.84,+0.4%',
#   '5.57',
#   '$24.08 billion',
#   '4.12 million',
#   '2.75 million',
#   'Analyst Report,Short Interest ↓,Analyst Revision'],
#  ['AVB,AvalonBay Communities',
#   '$172.08,-0.8%',
#   '19.58',
#   '$24.07 billion',
#   '709,948',
#   '763,604',
#   'Short Interest ↑'],
#  ['WY,Weyerhaeuser',
#   '$32.67,-0.7%',
#   '10.68',
#   '$24.04 billion',
#   '4.70 million',
#   '4.22 million',
#   'News Coverage'],
#  ['HIG,The Hartford Financial Services Group',
#   '$75.21,-0.8%',
#   '13.10',
#   '$23.92 billion',
#   '1.58 million',
#   '1.94 million',
#   'Insider Selling,News Coverage'],
#  ['TSCO,Tractor Supply',
#   '$215.32,+0.5%',
#   '23.38',
#   '$23.78 billion',
#   '1.01 million',
#   '1.15 million',
#   'Analyst Report,News Coverage'],
#  ['EBAY,eBay',
#   '$43.75,+0.1%',
#   'N/A',
#   '$23.74 billion',
#   '5.64 million',
#   '6.50 million',
#   'Analyst Report,Short Interest ↑'],
#  ['RJF,Raymond James',
#   '$110.28,-1.1%',
#   '15.80',
#   '$23.72 billion',
#   '1.07 million',
#   '1.25 million',
#   'Short Interest ↑'],
#  ['FTV,Fortive',
#   '$66.86,-1.3%',
#   '35.01',
#   '$23.66 billion',
#   '1.79 million',
#   '2.46 million',
#   ''],
#  ['ULTA,Ulta Beauty',
#   '$462.85,-0.3%',
#   '20.35',
#   '$23.55 billion',
#   '561,339',
#   '793,187',
#   'Analyst Downgrade,Positive News'],
#  ['DTE,DTE Energy',
#   '$120.60,+0.1%',
#   '20.87',
#   '$23.37 billion',
#   '2.14 million',
#   '1.23 million',
#   'Analyst Report,Short Interest ↓'],
#  ['AEE,Ameren',
#   '$89.79,-1.2%',
#   '22.50',
#   '$23.21 billion',
#   '1.47 million',
#   '1.36 million',
#   'Analyst Report'],
#  ['TSN,Tyson Foods',
#   '$64.35,-0.4%',
#   '7.21',
#   '$23.14 billion',
#   '2.84 million',
#   '2.41 million',
#   'Analyst Report'],
#  ['MKC,McCormick & Company, Incorporated',
#   '$86.27,-0.4%',
#   '33.70',
#   '$23.14 billion',
#   '1.15 million',
#   '1.33 million',
#   'Short Interest ↓'],
#  ['MLM,Martin Marietta Materials',
#   '$365.70,-0.8%',
#   '27.23',
#   '$22.71 billion',
#   '656,904',
#   '438,831',
#   'Analyst Downgrade'],
#  ['LUV,Southwest Airlines',
#   '$38.14,+1.0%',
#   '29.80',
#   '$22.65 billion',
#   '5.57 million',
#   '6.35 million',
#   'Analyst Revision'],
#  ['ANSS,ANSYS',
#   '$256.10,+0.6%',
#   '47.96',
#   '$22.31 billion',
#   '615,229',
#   '550,048',
#   'Analyst Upgrade,Short Interest ↓'],
#  ['FITB,Fifth Third Bancorp',
#   '$32.29,-2.0%',
#   '9.94',
#   '$22.16 billion',
#   '5.71 million',
#   '5.33 million',
#   'Dividend Announcement,News Coverage'],
#  ['IR,Ingersoll Rand',
#   '$54.73,-1.4%',
#   '32.97',
#   '$22.16 billion',
#   '3.01 million',
#   '2.79 million',
#   'Short Interest ↓'],
#  ['FRC,First Republic Bank',
#   '$122.98,-0.8%',
#   '14.66',
#   '$22.09 billion',
#   '2.26 million',
#   '1.34 million',
#   'Analyst Report,News Coverage'],
#  ['DAL,Delta Air Lines',
#   '$34.31,+2.8%',
#   '311.91',
#   '$22.00 billion',
#   '23.44 million',
#   '13.04 million',
#   'News Coverage,Gap Up'],
#  ['PWR,Quanta Services',
#   '$152.09,-0.3%',
#   '51.91',
#   '$21.73 billion',
#   '1.50 million',
#   '1.28 million',
#   'Dividend Increase,News Coverage'],
#  ['PPL,PPL',
#   '$29.42,+0.3%',
#   '30.97',
#   '$21.66 billion',
#   '4.99 million',
#   '5.53 million',
#   'Analyst Report,Analyst Revision'],
#  ['PFG,Principal Financial Group',
#   '$88.17,-1.9%',
#   '4.27',
#   '$21.57 billion',
#   '1.60 million',
#   '1.72 million',
#   'Short Interest ↑'],
#  ['VRSN,VeriSign',
#   '$200.86,-0.7%',
#   '26.71',
#   '$21.29 billion',
#   '726,254',
#   '681,917',
#   'Analyst Report'],
#  ['EXR,Extra Space Storage',
#   '$156.01,-1.0%',
#   '22.64',
#   '$20.89 billion',
#   '1.29 million',
#   '783,214',
#   'Analyst Report,Short Interest ↑'],
#  ['HPE,Hewlett Packard Enterprise',
#   '$16.20,-0.3%',
#   '24.55',
#   '$20.84 billion',
#   '14.92 million',
#   '11.81 million',
#   'Short Interest ↑'],
#  ['XYL,Xylem',
#   '$114.75,-0.2%',
#   '65.20',
#   '$20.68 billion',
#   '838,821',
#   '1.14 million',
#   ''],
#  ['CAH,Cardinal Health',
#   '$78.55,+0.4%',
#   '12.83',
#   '$20.59 billion',
#   '2.71 million',
#   '2.88 million',
#   'Short Interest ↑'],
#  ['WAT,Waters',
#   '$343.97,-0.2%',
#   '30.01',
#   '$20.43 billion',
#   '491,851',
#   '379,611',
#   'Analyst Report'],
#  ['LH,Laboratory Co. of America',
#   '$230.62,-0.2%',
#   '12.30',
#   '$20.43 billion',
#   '715,648',
#   '801,912',
#   'Analyst Downgrade'],
#  ['MOH,Molina Healthcare',
#   '$349.51,+0.2%',
#   '24.39',
#   '$20.41 billion',
#   '744,256',
#   '492,017',
#   'Analyst Upgrade,Insider Selling,News Coverage'],
#  ['EPAM,EPAM Systems',
#   '$354.83,-2.6%',
#   '51.65',
#   '$20.41 billion',
#   '332,061',
#   '757,171',
#   'News Coverage'],
#  ['HBAN,Huntington Bancshares',
#   '$13.93,-2.0%',
#   '10.80',
#   '$20.10 billion',
#   '28.70 million',
#   '14.55 million',
#   'Analyst Downgrade,Short Interest ↓,News Coverage'],
#  ['CHD,Church & Dwight',
#   '$82.21,+0.3%',
#   '27.50',
#   '$20.05 billion',
#   '1.51 million',
#   '1.59 million',
#   'Short Interest ↓'],
#  ['DOV,Dover',
#   '$140.70,-1.3%',
#   '17.48',
#   '$19.75 billion',
#   '788,670',
#   '947,674',
#   'Analyst Report,Short Interest ↑'],
#  ['TDY,Teledyne Technologies',
#   '$421.07,+0.0%',
#   '27.74',
#   '$19.74 billion',
#   '190,813',
#   '269,629',
#   'Analyst Upgrade,Insider Selling,News Coverage'],
#  ['RF,Regions Financial',
#   '$21.12,-2.4%',
#   '10.56',
#   '$19.74 billion',
#   '9.26 million',
#   '8.73 million',
#   ''],
#  ['PAYC,Paycom Software',
#   '$327.72,-0.3%',
#   '76.04',
#   '$19.67 billion',
#   '365,417',
#   '452,375',
#   ''],
#  ['AES,AES',
#   '$29.24,-0.1%',
#   'N/A',
#   '$19.53 billion',
#   '4.00 million',
#   '5.39 million',
#   'Analyst Report,Short Interest ↓'],
#  ['CNP,CenterPoint Energy',
#   '$30.95,+0.1%',
#   '12.84',
#   '$19.48 billion',
#   '3.37 million',
#   '4.49 million',
#   'Analyst Report,News Coverage'],
#  ['CTRA,Coterra Energy',
#   '$24.70,-0.8%',
#   '4.99',
#   '$19.48 billion',
#   '11.45 million',
#   '9.64 million',
#   'Analyst Downgrade,News Coverage'],
#  ['JBHT,J.B. Hunt Transport Services',
#   '$187.27,+1.6%',
#   '19.59',
#   '$19.39 billion',
#   '821,014',
#   '801,654',
#   'Positive News'],
#  ['WRB,W. R. Berkley',
#   '$72.99,-0.1%',
#   '15.73',
#   '$19.38 billion',
#   '1.08 million',
#   '1.37 million',
#   'Dividend Announcement'],
#  ['STE,STERIS',
#   '$193.72,-2.7%',
#   'N/A',
#   '$19.34 billion',
#   '612,332',
#   '539,143',
#   ''],
#  ['CFG,Citizens Financial Group',
#   '$39.06,-2.1%',
#   '9.77',
#   '$19.24 billion',
#   '4.26 million',
#   '5.16 million',
#   'Short Interest ↓'],
#  ['MAA,Mid-America Apartment Communities',
#   '$164.46,-0.7%',
#   '30.34',
#   '$18.99 billion',
#   '545,388',
#   '674,882',
#   'Dividend Increase,Short Interest ↑'],
#  ['WAB,Westinghouse Air Brake Technologies',
#   '$103.41,+0.4%',
#   '28.65',
#   '$18.81 billion',
#   '1.10 million',
#   '977,354',
#   'Analyst Report'],
#  ['ROL,Rollins',
#   '$38.13,-0.4%',
#   '54.47',
#   '$18.78 billion',
#   '2.56 million',
#   '1.66 million',
#   ''],
#  ['SEDG,SolarEdge Technologies',
#   '$335.61,+2.4%',
#   '165.33',
#   '$18.76 billion',
#   '1.12 million',
#   '1.04 million',
#   'Analyst Upgrade,Positive News'],
#  ['HOLX,Hologic',
#   '$75.89,+0.1%',
#   '14.82',
#   '$18.66 billion',
#   '1.49 million',
#   '1.73 million',
#   'News Coverage'],
#  ['AMCR,Amcor',
#   '$12.48,-0.6%',
#   '22.29',
#   '$18.58 billion',
#   '8.90 million',
#   '9.09 million',
#   ''],
#  ['VTR,Ventas',
#   '$46.47,+0.4%',
#   'N/A',
#   '$18.57 billion',
#   '2.10 million',
#   '2.19 million',
#   'Dividend Announcement,Short Interest ↑'],
#  ['MPWR,Monolithic Power Systems',
#   '$395.39,-1.5%',
#   '48.81',
#   '$18.56 billion',
#   '585,644',
#   '569,643',
#   'Analyst Report,Insider Selling,Short Interest ↑'],
#  ['CMS,CMS Energy',
#   '$63.76,-0.6%',
#   '14.26',
#   '$18.51 billion',
#   '1.86 million',
#   '1.96 million',
#   'Analyst Report,Short Interest ↑'],
#  ['CAG,Conagra Brands',
#   '$38.48,+0.7%',
#   '32.34',
#   '$18.44 billion',
#   '3.38 million',
#   '4.09 million',
#   ''],
#  ['INCY,Incyte',
#   '$82.67,-0.3%',
#   '21.04',
#   '$18.39 billion',
#   '1.14 million',
#   '1.50 million',
#   ''],
#  ['NTRS,Northern Trust',
#   '$88.24,-2.7%',
#   '12.02',
#   '$18.39 billion',
#   '730,550',
#   '964,381',
#   'Analyst Report,News Coverage,Positive News'],
#  ['GRMN,Garmin',
#   '$95.79,-0.4%',
#   '19.20',
#   '$18.36 billion',
#   '849,531',
#   '1.07 million',
#   'Short Interest ↓'],
#  ['GRMN,Garmin',
#   '$95.79,-0.4%',
#   '19.20',
#   '$18.36 billion',
#   '849,531',
#   '1.07 million',
#   'Short Interest ↓'],
#  ['CLX,Clorox',
#   '$148.26,+0.4%',
#   '45.48',
#   '$18.29 billion',
#   '723,589',
#   '1.31 million',
#   ''],
#  ['CF,CF Industries',
#   '$93.00,-4.9%',
#   '6.10',
#   '$18.25 billion',
# ...
#  ['MOS,Mosaic',
#   '$45.41,-3.4%',
#   '4.44',
#   '$15.46 billion',
#   '4.29 million',
#   '6.80 million',
#   'Short Interest ↓'],
#  ['ALGN,Align Technology',
#   '$195.81,-1.4%',
#   '30.26',
#   '$15.30 billion',
#   '689,594',
#   '981,207',
#   ''],
#  ['NVR,NVR',
#   '$4,746.65,+0.4%',
#   '10.60',
#   '$15.17 billion',
#   '19,173',
#   '21,644',
#   ''],
#  ['TXT,Textron',
#   '$72.02,+0.1%',
#   '18.61',
#   '$15.04 billion',
#   '1.28 million',
#   '1.26 million',
#   ''],
#  ['PTC,PTC',
#   '$127.30,+0.2%',
#   '48.04',
#   '$14.95 billion',
#   '487,564',
#   '754,474',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['AVY,Avery Dennison',
#   '$181.85,-1.9%',
#   '18.39',
#   '$14.72 billion',
#   '390,338',
#   '553,653',
#   ''],
#  ['TER,Teradyne',
#   '$94.15,-2.4%',
#   '21.06',
#   '$14.66 billion',
#   '1.46 million',
#   '1.84 million',
#   'Short Interest ↑'],
#  ['TER,Teradyne',
#   '$94.15,-2.4%',
#   '21.06',
#   '$14.66 billion',
#   '1.46 million',
#   '1.84 million',
#   'Short Interest ↑'],
#  ['TER,Teradyne',
#   '$94.15,-2.4%',
#   '21.06',
#   '$14.66 billion',
#   '1.46 million',
#   '1.84 million',
#   'Short Interest ↑'],
#  ['LDOS,Leidos',
#   '$106.80,+0.6%',
#   '21.84',
#   '$14.60 billion',
#   '1.23 million',
#   '857,719',
#   'Analyst Report,Insider Selling,Short Interest ↑,News Coverage'],
#  ['EXPE,Expedia Group',
#   '$92.79,-1.7%',
#   '33.99',
#   '$14.48 billion',
#   '2.56 million',
#   '2.97 million',
#   'Analyst Report,Short Interest ↓,Gap Down'],
#  ['APA,APA',
#   '$45.04,-1.7%',
#   '4.30',
#   '$14.48 billion',
#   '7.47 million',
#   '8.77 million',
#   'Dividend Announcement,Analyst Report'],
#  ['EVRG,Evergy',
#   '$63.05,-0.3%',
#   '18.22',
#   '$14.47 billion',
#   '1.71 million',
#   '1.49 million',
#   'Analyst Report,Short Interest ↑,Analyst Revision'],
#  ['LKQ,LKQ',
#   '$53.80,-1.2%',
#   '12.81',
#   '$14.37 billion',
#   '1.68 million',
#   '1.65 million',
#   'Short Interest ↑,Analyst Revision'],
#  ['ESS,Essex Property Trust',
#   '$220.94,-1.0%',
#   '40.03',
#   '$14.31 billion',
#   '718,081',
#   '432,926',
#   'Dividend Announcement,Analyst Downgrade,Short Interest ↓'],
#  ['MGM,MGM Resorts International',
#   '$36.93,-1.4%',
#   '12.65',
#   '$14.18 billion',
#   '6.59 million',
#   '5.40 million',
#   'Short Interest ↑'],
#  ['RCL,Royal Caribbean Cruises',
#   '$55.28,-0.9%',
#   'N/A',
#   '$14.11 billion',
#   '4.55 million',
#   '5.65 million',
#   'Insider Selling'],
#  ['FLT,FLEETCOR Technologies',
#   '$190.90,-0.2%',
#   '15.74',
#   '$14.08 billion',
#   '611,900',
#   '582,775',
#   'Short Interest ↓,Positive News'],
#  ['LNT,Alliant Energy',
#   '$56.05,-0.7%',
#   '21.15',
#   '$14.07 billion',
#   '1.83 million',
#   '1.48 million',
#   'Analyst Report'],
#  ['AKAM,Akamai Technologies',
#   '$88.84,-1.5%',
#   '28.47',
#   '$13.97 billion',
#   '1.14 million',
#   '1.62 million',
#   'Analyst Upgrade,Insider Selling,Short Interest ↓'],
#  ['TYL,Tyler Technologies',
#   '$334.61,-0.1%',
#   '75.53',
#   '$13.93 billion',
#   '180,682',
#   '248,490',
#   'Analyst Report,News Coverage'],
#  ['NTAP,NetApp',
#   '$64.39,-0.8%',
#   '9.74',
#   '$13.88 billion',
#   '1.43 million',
#   '1.75 million',
#   'Analyst Downgrade'],
#  ['VTRS,Viatris',
#   '$11.32,-0.2%',
#   '17.15',
#   '$13.73 billion',
#   '7.36 million',
#   '11.54 million',
#   'News Coverage'],
#  ['PEAK,Healthpeak Properties',
#   '$25.49,-0.5%',
#   '26.55',
#   '$13.70 billion',
#   '3.40 million',
#   '4.15 million',
#   'Analyst Downgrade,News Coverage'],
#  ['SIVB,SVB Financial Group',
#   '$230.57,-1.5%',
#   '8.56',
#   '$13.63 billion',
#   '967,556',
#   '693,199',
#   'Analyst Report,Short Interest ↑,Analyst Revision,News Coverage'],
#  ['TECH,Bio-Techne',
#   '$86.81,-0.2%',
#   '48.63',
#   '$13.63 billion',
#   '838,182',
#   '1.06 million',
#   'Analyst Upgrade,Short Interest ↑'],
#  ['KIM,Kimco Realty',
#   '$22.01,+0.3%',
#   '59.49',
#   '$13.61 billion',
#   '5.87 million',
#   '4.73 million',
#   'Analyst Report,Short Interest ↓'],
#  ['BEN,Franklin Resources',
#   '$27.10,-2.2%',
#   '10.75',
#   '$13.54 billion',
#   '4.15 million',
#   '3.13 million',
#   'Dividend Increase,Analyst Report'],
#  ['ZBRA,Zebra Technologies',
#   '$261.50,-0.7%',
#   '20.90',
#   '$13.50 billion',
#   '390,892',
#   '449,416',
#   'Analyst Report,Short Interest ↑,News Coverage'],
#  ['NDSN,Nordson',
#   '$235.91,-1.0%',
#   '28.56',
#   '$13.50 billion',
#   '342,365',
#   '278,726',
#   'Upcoming Earnings,Dividend Announcement,Analyst Downgrade,Analyst Revision,News Coverage'],
#  ['TRMB,Trimble',
#   '$54.56,-0.9%',
#   '28.72',
#   '$13.46 billion',
#   '1.81 million',
#   '1.26 million',
#   'Analyst Report,News Coverage'],
#  ['L,Loews',
#   '$56.25,-0.9%',
#   '14.06',
#   '$13.36 billion',
#   '1.01 million',
#   '856,592',
#   ''],
#  ['UDR,UDR',
#   '$40.58,-0.8%',
#   '82.82',
#   '$13.21 billion',
#   '3.42 million',
#   '2.03 million',
#   ''],
#  ['IP,International Paper',
#   '$37.10,-0.3%',
#   '7.07',
#   '$13.20 billion',
#   '2.63 million',
#   '3.27 million',
#   'Short Interest ↓'],
#  ['JKHY,Jack Henry & Associates',
#   '$180.59,-1.4%',
#   '35.97',
#   '$13.17 billion',
#   '516,888',
#   '525,077',
#   ''],
#  ['NLOK,NortonLifeLock',
#   '$22.99,-0.1%',
#   '16.08',
#   '$13.14 billion',
#   '2.25 million',
#   '5.78 million',
#   ''],
#  ['UAL,United Airlines',
#   '$40.10,-2.6%',
#   'N/A',
#   '$13.10 billion',
#   '13.83 million',
#   '11.81 million',
#   'News Coverage'],
#  ['POOL,Pool',
#   '$334.81,-0.2%',
#   '17.20',
#   '$13.07 billion',
#   '607,071',
#   '435,102',
#   ''],
#  ['IPG,Interpublic Group of Companies',
#   '$33.45,-0.1%',
#   '13.27',
#   '$13.00 billion',
#   '4.16 million',
#   '3.56 million',
#   'Short Interest ↑,News Coverage'],
#  ["DPZ,Domino's Pizza",
#   '$366.74,+1.6%',
#   '29.67',
#   '$12.98 billion',
#   '640,923',
#   '604,310',
#   ''],
#  ['BIO,Bio-Rad Laboratories',
#   '$429.90,-1.2%',
#   'N/A',
#   '$12.82 billion',
#   '194,372',
#   '211,389',
#   'Short Interest ↓'],
#  ['RE,Everest Re Group',
#   '$325.39,-1.8%',
#   '24.30',
#   '$12.74 billion',
#   '444,721',
#   '272,868',
#   'Short Interest ↓,Positive News'],
#  ['HST,Host Hotels & Resorts',
#   '$17.58,-2.7%',
#   '15.56',
#   '$12.57 billion',
#   '8.16 million',
#   '8.26 million',
#   ''],
#  ['PARA,Paramount Global',
#   '$19.36,-0.4%',
#   '4.12',
#   '$12.57 billion',
#   '8.29 million',
#   '11.61 million',
#   ''],
#  ['LW,Lamb Weston',
#   '$87.08,+1.1%',
#   '31.44',
#   '$12.52 billion',
#   '1.54 million',
#   '1.42 million',
#   'Dividend Increase,Short Interest ↑,News Coverage'],
#  ['PKG,Packaging Co. of America',
#   '$135.33,-0.9%',
#   '12.33',
#   '$12.52 billion',
#   '624,507',
#   '700,481',
#   'Dividend Announcement'],
#  ['MTCH,Match Group',
#   '$44.56,-5.0%',
#   '135.03',
#   '$12.45 billion',
#   '5.27 million',
#   '3.43 million',
#   ''],
#  ['CPT,Camden Property Trust',
#   '$116.78,-1.4%',
#   '15.39',
#   '$12.44 billion',
#   '815,481',
#   '975,858',
#   'Short Interest ↑'],
#  ['SNA,Snap-on',
#   '$233.00,-1.4%',
#   '14.11',
#   '$12.39 billion',
#   '443,187',
#   '331,039',
#   'Insider Selling'],
#  ['SWK,Stanley Black & Decker',
#   '$81.28,-1.8%',
#   '8.91',
#   '$12.02 billion',
#   '1.47 million',
#   '1.96 million',
#   ''],
#  ['TFX,Teleflex',
#   '$253.28,-0.1%',
#   '29.05',
#   '$11.88 billion',
#   '618,815',
#   '387,915',
#   'Short Interest ↓'],
#  ['CE,Celanese',
#   '$105.98,-2.8%',
#   '7.00',
#   '$11.49 billion',
#   '1.27 million',
#   '1.06 million',
#   'Short Interest ↓'],
#  ['GL,Globe Life',
#   '$118.08,+1.1%',
#   '16.65',
#   '$11.49 billion',
#   '960,908',
#   '563,145',
#   'Dividend Announcement,Short Interest ↑,News Coverage'],
#  ['TAP,Molson Coors Beverage',
#   '$52.89,+0.5%',
#   '23.20',
#   '$11.45 billion',
#   '1.17 million',
#   '1.47 million',
#   ''],
#  ['WDC,Western Digital',
#   '$35.83,-1.3%',
#   '12.36',
#   '$11.38 billion',
#   '3.63 million',
#   '4.20 million',
#   ''],
#  ['CHRW,C.H. Robinson Worldwide',
#   '$96.21,+0.7%',
#   '11.68',
#   '$11.32 billion',
#   '1.75 million',
#   '1.36 million',
#   'Short Interest ↑'],
#  ['MAS,Masco',
#   '$50.14,-2.5%',
#   '13.63',
#   '$11.31 billion',
#   '2.25 million',
#   '2.15 million',
#   'Analyst Report,Insider Selling,Short Interest ↑'],
#  ['STX,Seagate Technology',
#   '$54.75,-2.5%',
#   '10.53',
#   '$11.30 billion',
#   '2.19 million',
#   '2.23 million',
#   ''],
#  ['NI,NiSource',
#   '$27.82,-0.4%',
#   '18.07',
#   '$11.30 billion',
#   '3.46 million',
#   '4.67 million',
#   'Analyst Report,Short Interest ↓'],
#  ['HSIC,Henry Schein',
#   '$83.17,-0.1%',
#   '18.08',
#   '$11.27 billion',
#   '1.05 million',
#   '937,974',
#   'Insider Selling,Short Interest ↑,News Coverage'],
#  ['REG,Regency Centers',
#   '$65.53,-0.2%',
#   '24.73',
#   '$11.21 billion',
#   '1.48 million',
#   '961,769',
#   ''],
#  ['NWS,News',
#   '$18.98,+0.1%',
#   '23.73',
#   '$10.93 billion',
#   '1.34 million',
#   '727,326',
#   'Positive News'],
#  ['CRL,Charles River Laboratories International',
#   '$214.33,+2.3%',
#   '25.25',
#   '$10.90 billion',
#   '884,863',
#   '565,670',
#   ''],
#  ['BXP,Boston Properties',
#   '$69.54,+2.2%',
#   '11.99',
#   '$10.90 billion',
#   '3.20 million',
#   '1.20 million',
#   'Analyst Report,News Coverage,High Trading Volume'],
#  ['VFC,V.F.',
#   '$28.04,-1.3%',
#   '25.96',
#   '$10.90 billion',
#   '8.69 million',
#   '4.21 million',
#   'Insider Buying,High Trading Volume'],
#  ['NWSA,News',
#   '$18.68,-0.1%',
#   '23.35',
#   '$10.75 billion',
#   '2.26 million',
#   '2.92 million',
#   'Positive News'],
#  ['MKTX,MarketAxess',
#   '$285.53,-1.4%',
#   '44.34',
#   '$10.75 billion',
#   '307,144',
#   '351,885',
#   ''],
#  ['JNPR,Juniper Networks',
#   '$33.08,-0.2%',
#   '25.64',
#   '$10.74 billion',
#   '2.63 million',
#   '3.93 million',
#   'Analyst Report,News Coverage'],
#  ['KMX,CarMax',
#   '$67.71,+0.8%',
#   '13.65',
#   '$10.70 billion',
#   '2.69 million',
#   '1.83 million',
#   'Short Interest ↑'],
#  ['CZR,Caesars Entertainment',
#   '$49.69,-5.4%',
#   'N/A',
#   '$10.66 billion',
#   '3.25 million',
#   '3.64 million',
#   'Analyst Downgrade'],
#  ['PHM,PulteGroup',
#   '$46.33,+1.2%',
#   '4.70',
#   '$10.55 billion',
#   '2.73 million',
#   '2.70 million',
#   'Analyst Upgrade'],
#  ['CDAY,Ceridian HCM',
#   '$69.15,-0.2%',
#   'N/A',
#   '$10.49 billion',
#   '951,746',
#   '1.68 million',
#   'Short Interest ↑,News Coverage'],
#  ['EMN,Eastman Chemical',
#   '$86.33,-1.1%',
#   '9.49',
#   '$10.36 billion',
#   '1.14 million',
#   '1.14 million',
#   'Short Interest ↓'],
#  ['QRVO,Qorvo',
#   '$100.94,-1.2%',
#   '15.85',
#   '$10.23 billion',
#   '1.09 million',
#   '1.36 million',
#   'Insider Selling,News Coverage'],
#  ['CCL,Carnival Co. &',
#   '$8.93,+0.2%',
#   'N/A',
#   '$9.94 billion',
#   '57.44 million',
#   '49.49 million',
#   'Upcoming Earnings,Analyst Report,Short Interest ↑,News Coverage'],
#  ['WYNN,Wynn Resorts',
#   '$86.32,-0.4%',
#   'N/A',
#   '$9.78 billion',
#   '1.61 million',
#   '3.35 million',
#   ''],
#  ['BBWI,Bath & Body Works',
#   '$42.22,-0.4%',
#   '10.99',
#   '$9.64 billion',
#   '2.12 million',
#   '4.62 million',
#   ''],
#  ['ALLE,Allegion',
#   '$109.77,-1.8%',
#   '22.36',
#   '$9.64 billion',
#   '674,421',
#   '742,071',
#   'Short Interest ↓'],
#  ['BWA,BorgWarner',
#   '$41.16,+0.1%',
#   '11.93',
#   '$9.64 billion',
#   '1.90 million',
#   '2.01 million',
#   'Insider Selling'],
#  ['WRK,WestRock',
#   '$36.78,-0.3%',
#   '10.10',
#   '$9.36 billion',
#   '1.45 million',
#   '2.19 million',
#   'Insider Selling'],
#  ['UHS,Universal Health Services',
#   '$130.83,+1.1%',
#   '13.46',
#   '$9.34 billion',
#   '877,976',
#   '751,911',
#   'Analyst Report,News Coverage'],
#  ['HII,Huntington Ingalls Industries',
#   '$233.38,+0.6%',
#   '16.24',
#   '$9.31 billion',
#   '275,584',
#   '396,501',
#   'Short Interest ↑'],
#  ['FFIV,F5',
#   '$152.07,-1.6%',
#   '28.75',
#   '$9.18 billion',
#   '447,766',
#   '572,375',
#   'Analyst Report,Insider Selling,Short Interest ↓'],
#  ['TPR,Tapestry',
#   '$38.06,-0.8%',
#   '12.08',
#   '$9.17 billion',
#   '2.93 million',
#   '3.85 million',
#   'Analyst Upgrade'],
#  ['AOS,A. O. Smith',
#   '$58.88,-0.8%',
#   '18.69',
#   '$9.00 billion',
#   '1.20 million',
#   '1.10 million',
#   ''],
#  ['PNW,Pinnacle West Capital',
#   '$79.45,+0.1%',
#   '16.83',
#   '$8.99 billion',
#   '669,588',
#   '814,448',
#   'Dividend Announcement,Analyst Report,News Coverage'],
#  ['IVZ,Invesco',
#   '$19.52,-0.5%',
#   '9.76',
#   '$8.88 billion',
#   '4.96 million',
#   '4.74 million',
#   'Analyst Report,Short Interest ↓'],
#  ['FRT,Federal Realty Investment Trust',
#   '$108.78,+0.2%',
#   '23.10',
#   '$8.83 billion',
#   '653,881',
#   '567,838',
#   'Positive News'],
#  ['AAL,American Airlines Group',
#   '$13.35,-0.8%',
#   'N/A',
#   '$8.68 billion',
#   '33.60 million',
#   '36.02 million',
#   'News Coverage'],
#  ['AAP,Advance Auto Parts',
#   '$143.46,-1.5%',
#   '18.44',
#   '$8.62 billion',
#   '1.29 million',
#   '876,352',
#   'Short Interest ↓'],
#  ['CMA,Comerica',
#   '$65.09,-0.8%',
#   '8.62',
#   '$8.52 billion',
#   '1.61 million',
#   '1.38 million',
#   'Analyst Downgrade,Short Interest ↓,News Coverage'],
#  ['DISH,DISH Network',
#   '$15.74,-2.5%',
#   '5.21',
#   '$8.35 billion',
#   '4.92 million',
#   '3.81 million',
#   'Analyst Report,Gap Down'],
#  ['CTLT,Catalent',
#   '$46.26,-1.1%',
#   '19.77',
#   '$8.33 billion',
#   '2.20 million',
#   '1.68 million',
#   'Short Interest ↑'],
#  ['HAS,Hasbro',
#   '$59.96,-1.2%',
#   '20.12',
#   '$8.28 billion',
#   '1.77 million',
#   '1.28 million',
#   'Short Interest ↓'],
#  ['RHI,Robert Half International',
#   '$75.59,-0.6%',
#   '12.27',
#   '$8.20 billion',
#   '1.07 million',
#   '1.00 million',
#   'News Coverage'],
#  ['WHR,Whirlpool',
#   '$146.00,-1.0%',
#   '23.51',
#   '$7.95 billion',
#   '656,280',
#   '933,034',
#   ''],
#  ['FBHS,Fortune Brands Home & Security',
#   '$61.90,-2.1%',
#   '10.96',
#   '$7.94 billion',
#   '2.25 million',
#   '1.35 million',
#   'Short Interest ↑'],
#  ['SEE,Sealed Air',
#   '$52.61,+0.1%',
#   '13.52',
#   '$7.61 billion',
#   '857,862',
#   '993,660',
#   ''],
#  ['PNR,Pentair',
#   '$45.84,-1.6%',
#   '14.28',
#   '$7.54 billion',
#   '1.47 million',
#   '1.47 million',
#   'Dividend Increase,Analyst Downgrade'],
#  ['NRG,NRG Energy',
#   '$32.47,-2.8%',
#   '4.12',
#   '$7.48 billion',
#   '4.23 million',
#   '3.04 million',
#   ''],
#  ['SBNY,Signature Bank',
#   '$116.65,-2.8%',
#   '5.70',
#   '$7.34 billion',
#   '1.29 million',
#   '971,113',
#   'Analyst Report'],
#  ['RL,Ralph Lauren',
#   '$110.47,-0.6%',
#   '15.39',
#   '$7.29 billion',
#   '719,420',
#   '1.03 million',
#   'Analyst Report'],
#  ['OGN,Organon & Co.',
#   '$28.62,+1.5%',
#   '7.23',
#   '$7.28 billion',
#   '2.36 million',
#   '1.87 million',
#   ''],
#  ['ZION,Zions Bancorporation, National Association',
#   '$47.54,-1.5%',
#   '8.97',
#   '$7.11 billion',
#   '1.06 million',
#   '1.48 million',
#   'Analyst Report'],
#  ['XRAY,DENTSPLY SIRONA',
#   '$32.05,+1.2%',
#   '17.32',
#   '$6.89 billion',
#   '2.62 million',
#   '2.23 million',
#   ''],
#  ['DVA,DaVita',
#   '$74.71,-0.5%',
#   '10.94',
#   '$6.73 billion',
#   '791,128',
#   '804,932',
#   ''],
#  ['AIZ,Assurant',
#   '$125.64,-3.6%',
#   '21.59',
#   '$6.64 billion',
#   '542,824',
#   '498,075',
#   'Short Interest ↓'],
#  ['MHK,Mohawk Industries',
#   '$101.94,-1.2%',
#   '39.51',
#   '$6.48 billion',
#   '596,636',
#   '646,231',
#   'Analyst Report,Insider Selling,News Coverage'],
#  ['GNRC,Generac',
#   '$101.15,+2.4%',
#   '15.21',
#   '$6.41 billion',
#   '2.02 million',
#   '1.32 million',
#   'Analyst Report,News Coverage'],
#  ['NCLH,Norwegian Cruise Line',
#   '$15.08,+0.3%',
#   'N/A',
#   '$6.35 billion',
#   '17.45 million',
#   '21.03 million',
#   'Analyst Downgrade'],
#  ['DXC,DXC Technology',
#   '$27.29,+0.1%',
#   '8.89',
#   '$6.28 billion',
#   '1.17 million',
#   '2.24 million',
#   ''],
#  ['LUMN,Lumen Technologies',
#   '$5.77,+1.6%',
#   '2.89',
#   '$5.97 billion',
#   '20.66 million',
#   '15.67 million',
#   'Short Interest ↑'],
#  ['ALK,Alaska Air Group',
#   '$45.74,+1.0%',
#   '114.35',
#   '$5.80 billion',
#   '1.53 million',
#   '1.76 million',
#   'Analyst Upgrade,News Coverage'],
#  ['NWL,Newell Brands',
#   '$13.66,-1.2%',
#   '10.27',
#   '$5.65 billion',
#   '3.63 million',
#   '3.59 million',
#   'Short Interest ↑'],
#  ['NWL,Newell Brands',
#   '$13.66,-1.2%',
#   '9.17',
#   '$5.65 billion',
#   '3.63 million',
#   '3.59 million',
#   'Analyst Downgrade'],
#  ['LNC,Lincoln National',
#   '$32.38,-0.3%',
#   'N/A',
#   '$5.48 billion',
#   '2.90 million',
#   '1.83 million',
#   'Analyst Report,Short Interest ↓'],
#  ['PENN,PENN Entertainment',
#   '$33.51,-4.4%',
#   '23.60',
#   '$5.20 billion',
#   '2.77 million',
#   '3.88 million',
#   'Analyst Downgrade,Short Interest ↑,Gap Down'],
#  ['PVH,PVH',
#   '$72.28,-1.6%',
#   '11.45',
#   '$4.71 billion',
#   '976,055',
#   '1.44 million',
#   'Insider Selling'],
#  ['VNO,Vornado Realty Trust',
#   '$22.97,-0.4%',
#   '45.94',
#   '$4.41 billion',
#   '3.05 million',
#   '2.18 million',
#   'Analyst Downgrade,Short Interest ↑'],
#  ['EMBC,Embecta',
#   '$35.14,-1.0%',
#   'N/A',
#   '$2.03 billion',
#   '390,156',
#   '862,897',
#   'Upcoming Earnings,Short Interest ↓,News Coverage']]

# %%
# Inserting the Table data with the headers inside the DataFrame
web_df = pd.DataFrame(data, columns = headers)

# %%
# Display the DataFrame after Web Scraping
web_df.head()
# Out:
#                   Company  Current Price PE Ratio       Market Cap  \
# 0          MSFT,Microsoft  $257.22,+0.1%    27.72   $1.92 trillion
# 1           GOOG,Alphabet   $95.31,-0.6%    18.93   $1.23 trillion
# 2          GOOGL,Alphabet   $95.07,-0.6%    18.88   $1.23 trillion
# 3         AMZN,Amazon.com   $91.58,-1.0%    84.06  $934.27 billion
# 4  UNH,UnitedHealth Group  $538.36,+0.0%    26.36  $503.02 billion
#
#           Volume Average Volume      Indicator(s)
# 0  35.04 million  31.30 million  Short Interest ↑
# 1  26.17 million  28.88 million  Short Interest ↓
# 2  28.40 million  35.06 million
# 3  69.69 million  76.16 million  Short Interest ↓
# 4   2.61 million   3.13 million

# %% [markdown]
# ### Data Scraping using API
# We will be scraping stock market prices data from the Yahoo Finance API. The Yahoo Finance API is used to obtain historical and real time data for a variety of financial markets and products. yfinance is a popular open source library which is free and easy to setup with high granularity of data.

# %%
import yfinance as yf # Library required for connecting to the Yahoo Finance API

# %%
# Generate daily OHLC data for the tickers
ticker_list = ['AAPL', 'MSFT', 'AMZN', 'TSLA']
daily_df = yf.download(ticker_list, group_by='Ticker', period='11mo', interval='1d')
daily_df = daily_df.stack(level=0).rename_axis(['Date', 'Ticker']).reset_index(level=1)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
daily_df.head()
# Out:
#            Ticker   Adj Close       Close        High         Low        Open  \
# Date
# 2022-01-18   AAPL  168.820190  169.800003  172.539993  169.410004  171.509995
# 2022-01-18   AMZN  158.917496  158.917496  159.734497  157.664505  159.104996
# 2022-01-18   MSFT  299.840424  302.649994  309.799988  301.739990  304.070007
# 2022-01-18   TSLA  343.503326  343.503326  356.929993  338.686676  342.203339
# 2022-01-19   AAPL  165.270798  166.229996  171.080002  165.940002  170.000000
#
#               Volume
# Date
# 2022-01-18  90956700
# 2022-01-18  67292000
# 2022-01-18  42333200
# 2022-01-18  66743400
# 2022-01-19  94815000

# %%
# Generate daily OHLC data for the tickers
ticker_list = ['AAPL', 'MSFT', 'AMZN', 'TSLA']
hourly_df = yf.download(ticker_list, group_by='Ticker', period='1d', interval='1h')
hourly_df = hourly_df.stack(level=0).rename_axis(['Date', 'Ticker']).reset_index(level=1)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
hourly_df.head()
# Out:
#                     Ticker   Adj Close       Close        High         Low  \
# Date
# 2022-12-14 09:30:00   AAPL  146.000000  146.000000  146.654999  145.070007
# 2022-12-14 09:30:00   AMZN   93.149902   93.149902   93.379898   92.279999
# 2022-12-14 09:30:00   MSFT  260.859985  260.859985  261.000000  256.920013
# 2022-12-14 09:30:00   TSLA  158.258606  158.258606  161.619995  157.339996
# 2022-12-14 10:30:00   AAPL  146.074997  146.074997  146.384995  145.580002
#
#                            Open    Volume
# Date
# 2022-12-14 09:30:00  145.350006   9784672
# 2022-12-14 09:30:00   92.501999  11490960
# 2022-12-14 09:30:00  257.130005   5069260
# 2022-12-14 09:30:00  159.250000  37342162
# 2022-12-14 10:30:00  146.009995   8606074

# %% [markdown]
# ## Data Munging
# Data Munging (or Data Wrangling) is the process of preparing your data for a dedicated purpose - taking the data from its raw state and transforming and mapping into another format, normally for use beyond its original intent.

# %% [markdown]
# ### Data Munging on CSV DataFrame

# %%
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
# 2    ABT       Abbott  Health Care     Health Care Equipment
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed  Health Care     Health Care Equipment
#
#      Headquarters Location      Founded
# 0    Saint Paul, Minnesota         1902
# 1     Milwaukee, Wisconsin         1916
# 2  North Chicago, Illinois         1888
# 3  North Chicago, Illinois  2013 (1888)
# 4   Danvers, Massachusetts         1981

# %%
# Renaming columns for further processing
csv_df=csv_df.rename(columns = {'Headquarters Location':'Location'})

# %%
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
# 2    ABT       Abbott  Health Care     Health Care Equipment
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed  Health Care     Health Care Equipment
#
#                   Location      Founded
# 0    Saint Paul, Minnesota         1902
# 1     Milwaukee, Wisconsin         1916
# 2  North Chicago, Illinois         1888
# 3  North Chicago, Illinois  2013 (1888)
# 4   Danvers, Massachusetts         1981

# %%
# Splitting the 'Location' column into two columns for more authenticity
csv_df1 = pd.DataFrame(csv_df.Location.str.split(',',1).tolist(), columns = ['Headquarters','City'])

# %%
csv_df1
# Out:
#        Headquarters            City
# 0        Saint Paul       Minnesota
# 1         Milwaukee       Wisconsin
# 2     North Chicago        Illinois
# 3     North Chicago        Illinois
# 4           Danvers   Massachusetts
# ..              ...             ...
# 498      Louisville        Kentucky
# 499    Lincolnshire        Illinois
# 500          Warsaw         Indiana
# 501  Salt Lake City            Utah
# 502      Parsippany      New Jersey
#
# [503 rows x 2 columns]

# %%
# Replace the 'Location' column with 'Headquarters'
csv_df['Location'] = csv_df1['Headquarters']
# Insert the 'City' column
csv_df.insert(5, 'City', csv_df1['City'])

# %%
# Display CSV DataFrame after performing Data Munging
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry       Location  \
# 0    MMM           3M  Industrials  Industrial Conglomerates     Saint Paul
# 1    AOS  A. O. Smith  Industrials         Building Products      Milwaukee
# 2    ABT       Abbott  Health Care     Health Care Equipment  North Chicago
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals  North Chicago
# 4   ABMD      Abiomed  Health Care     Health Care Equipment        Danvers
#
#              City      Founded
# 0       Minnesota         1902
# 1       Wisconsin         1916
# 2        Illinois         1888
# 3        Illinois  2013 (1888)
# 4   Massachusetts         1981

# %% [markdown]
# ### Data Munging on Web Scraping DataFrame

# %%
web_df.head()
# Out:
#                   Company  Current Price PE Ratio       Market Cap  \
# 0          MSFT,Microsoft  $257.22,+0.1%    27.72   $1.92 trillion
# 1           GOOG,Alphabet   $95.31,-0.6%    18.93   $1.23 trillion
# 2          GOOGL,Alphabet   $95.07,-0.6%    18.88   $1.23 trillion
# 3         AMZN,Amazon.com   $91.58,-1.0%    84.06  $934.27 billion
# 4  UNH,UnitedHealth Group  $538.36,+0.0%    26.36  $503.02 billion
#
#           Volume Average Volume      Indicator(s)
# 0  35.04 million  31.30 million  Short Interest ↑
# 1  26.17 million  28.88 million  Short Interest ↓
# 2  28.40 million  35.06 million
# 3  69.69 million  76.16 million  Short Interest ↓
# 4   2.61 million   3.13 million

# %%
# Renaming columns for further processing
web_df = web_df.rename(columns = {'Current Price':'Price'})
web_df = web_df.rename(columns = {'Market Cap':'Market_Cap'})
web_df = web_df.rename(columns = {'PE Ratio':'PE_Ratio'})
web_df = web_df.rename(columns = {'Average Volume':'Average_Volume'})

# %%
# Splitting the 'Company' column into 'Symbol' and 'Company' columns for more authenticity
web_df1 = pd.DataFrame(web_df.Company.str.split(',',1).tolist(), columns = ['Symbol','Company'])

# %%
web_df1.head()
# Out:
#   Symbol             Company
# 0   MSFT           Microsoft
# 1   GOOG            Alphabet
# 2  GOOGL            Alphabet
# 3   AMZN          Amazon.com
# 4    UNH  UnitedHealth Group

# %%
# Splitting the 'Price' column into 'Price' and 'Price_Change_Percent' columns for more authenticity
web_df2 = pd.DataFrame(web_df.Price.str.split(',',1).tolist(), columns = ['Price','Price_Change_Percent'])
web_df2['Price'] = web_df2['Price'].str.replace('$', '')
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_32572\775149396.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   web_df2['Price'] = web_df2['Price'].str.replace('$', '')

# %%
web_df2.head()
# Out:
#     Price Price_Change_Percent
# 0  257.22                +0.1%
# 1   95.31                -0.6%
# 2   95.07                -0.6%
# 3   91.58                -1.0%
# 4  538.36                +0.0%

# %%
web_df
# Out:
#                       Company          Price PE_Ratio       Market_Cap  \
# 0              MSFT,Microsoft  $257.22,+0.1%    27.72   $1.92 trillion
# 1               GOOG,Alphabet   $95.31,-0.6%    18.93   $1.23 trillion
# 2              GOOGL,Alphabet   $95.07,-0.6%    18.88   $1.23 trillion
# 3             AMZN,Amazon.com   $91.58,-1.0%    84.06  $934.27 billion
# 4      UNH,UnitedHealth Group  $538.36,+0.0%    26.36  $503.02 billion
# ..                        ...            ...      ...              ...
# 495      LNC,Lincoln National   $32.38,-0.3%      N/A    $5.48 billion
# 496   PENN,PENN Entertainment   $33.51,-4.4%    23.60    $5.20 billion
# 497                   PVH,PVH   $72.28,-1.6%    11.45    $4.71 billion
# 498  VNO,Vornado Realty Trust   $22.97,-0.4%    45.94    $4.41 billion
# 499              EMBC,Embecta   $35.14,-1.0%      N/A    $2.03 billion
#
#             Volume Average_Volume  \
# 0    35.04 million  31.30 million
# 1    26.17 million  28.88 million
# 2    28.40 million  35.06 million
# 3    69.69 million  76.16 million
# 4     2.61 million   3.13 million
# ..             ...            ...
# 495   2.90 million   1.83 million
# 496   2.77 million   3.88 million
# 497        976,055   1.44 million
# 498   3.05 million   2.18 million
# 499        390,156        862,897
#
#                                          Indicator(s)
# 0                                    Short Interest ↑
# 1                                    Short Interest ↓
# 2
# 3                                    Short Interest ↓
# 4
# ..                                                ...
# 495                   Analyst Report,Short Interest ↓
# 496       Analyst Downgrade,Short Interest ↑,Gap Down
# 497                                   Insider Selling
# 498                Analyst Downgrade,Short Interest ↑
# 499  Upcoming Earnings,Short Interest ↓,News Coverage
#
# [500 rows x 7 columns]

# %%
# Dropping unwanted columns from the dataframe
web_df = web_df.drop(['Company', 'Price', 'Indicator(s)'], axis=1)
# Manipulating column into appropriate format for insertion
web_df['Market_Cap'] = web_df['Market_Cap'].str.replace('$', '')
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_32572\2257351460.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   web_df['Market_Cap'] = web_df['Market_Cap'].str.replace('$', '')

# %%
# Concatenate all the DataFrames into a single DataFrame
final_web_df = pd.concat([web_df1, web_df2, web_df], axis=1)

# %%
final_web_df
# Out:
#     Symbol               Company   Price Price_Change_Percent PE_Ratio  \
# 0     MSFT             Microsoft  257.22                +0.1%    27.72
# 1     GOOG              Alphabet   95.31                -0.6%    18.93
# 2    GOOGL              Alphabet   95.07                -0.6%    18.88
# 3     AMZN            Amazon.com   91.58                -1.0%    84.06
# 4      UNH    UnitedHealth Group  538.36                +0.0%    26.36
# ..     ...                   ...     ...                  ...      ...
# 495    LNC      Lincoln National   32.38                -0.3%      N/A
# 496   PENN    PENN Entertainment   33.51                -4.4%    23.60
# 497    PVH                   PVH   72.28                -1.6%    11.45
# 498    VNO  Vornado Realty Trust   22.97                -0.4%    45.94
# 499   EMBC               Embecta   35.14                -1.0%      N/A
#
#          Market_Cap         Volume Average_Volume
# 0     1.92 trillion  35.04 million  31.30 million
# 1     1.23 trillion  26.17 million  28.88 million
# 2     1.23 trillion  28.40 million  35.06 million
# 3    934.27 billion  69.69 million  76.16 million
# 4    503.02 billion   2.61 million   3.13 million
# ..              ...            ...            ...
# 495    5.48 billion   2.90 million   1.83 million
# 496    5.20 billion   2.77 million   3.88 million
# 497    4.71 billion        976,055   1.44 million
# 498    4.41 billion   3.05 million   2.18 million
# 499    2.03 billion        390,156        862,897
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Data Munging on API DataFrame

# %%
daily_df.head()
# Out:
#            Ticker   Adj Close       Close        High         Low        Open  \
# Date
# 2022-01-18   AAPL  168.820190  169.800003  172.539993  169.410004  171.509995
# 2022-01-18   AMZN  158.917496  158.917496  159.734497  157.664505  159.104996
# 2022-01-18   MSFT  299.840424  302.649994  309.799988  301.739990  304.070007
# 2022-01-18   TSLA  343.503326  343.503326  356.929993  338.686676  342.203339
# 2022-01-19   AAPL  165.270798  166.229996  171.080002  165.940002  170.000000
#
#               Volume
# Date
# 2022-01-18  90956700
# 2022-01-18  67292000
# 2022-01-18  42333200
# 2022-01-18  66743400
# 2022-01-19  94815000

# %%
hourly_df.head()
# Out:
#                     Ticker   Adj Close       Close        High         Low  \
# Date
# 2022-12-14 09:30:00   AAPL  146.000000  146.000000  146.654999  145.070007
# 2022-12-14 09:30:00   AMZN   93.149902   93.149902   93.379898   92.279999
# 2022-12-14 09:30:00   MSFT  260.859985  260.859985  261.000000  256.920013
# 2022-12-14 09:30:00   TSLA  158.258606  158.258606  161.619995  157.339996
# 2022-12-14 10:30:00   AAPL  146.074997  146.074997  146.384995  145.580002
#
#                            Open    Volume
# Date
# 2022-12-14 09:30:00  145.350006   9784672
# 2022-12-14 09:30:00   92.501999  11490960
# 2022-12-14 09:30:00  257.130005   5069260
# 2022-12-14 09:30:00  159.250000  37342162
# 2022-12-14 10:30:00  146.009995   8606074

# %%
# Resetting the Date index into a column
daily_df.reset_index(inplace=True)

# %%
daily_df.head()
# Out:
#         Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-01-18   AAPL  168.820190  169.800003  172.539993  169.410004
# 1 2022-01-18   AMZN  158.917496  158.917496  159.734497  157.664505
# 2 2022-01-18   MSFT  299.840424  302.649994  309.799988  301.739990
# 3 2022-01-18   TSLA  343.503326  343.503326  356.929993  338.686676
# 4 2022-01-19   AAPL  165.270798  166.229996  171.080002  165.940002
#
#          Open    Volume
# 0  171.509995  90956700
# 1  159.104996  67292000
# 2  304.070007  42333200
# 3  342.203339  66743400
# 4  170.000000  94815000

# %%
# Resetting the Date index into a column
hourly_df.reset_index(inplace=True)

# %%
hourly_df.head()
# Out:
#                  Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-12-14 09:30:00   AAPL  146.000000  146.000000  146.654999  145.070007
# 1 2022-12-14 09:30:00   AMZN   93.149902   93.149902   93.379898   92.279999
# 2 2022-12-14 09:30:00   MSFT  260.859985  260.859985  261.000000  256.920013
# 3 2022-12-14 09:30:00   TSLA  158.258606  158.258606  161.619995  157.339996
# 4 2022-12-14 10:30:00   AAPL  146.074997  146.074997  146.384995  145.580002
#
#          Open    Volume
# 0  145.350006   9784672
# 1   92.501999  11490960
# 2  257.130005   5069260
# 3  159.250000  37342162
# 4  146.009995   8606074

# %% [markdown]
# ## Data Cleaning
# Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate or incomplete data within a dataset.

# %% [markdown]
# ### Data Cleaning on CSV DataFrame

# %%
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry       Location  \
# 0    MMM           3M  Industrials  Industrial Conglomerates     Saint Paul
# 1    AOS  A. O. Smith  Industrials         Building Products      Milwaukee
# 2    ABT       Abbott  Health Care     Health Care Equipment  North Chicago
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals  North Chicago
# 4   ABMD      Abiomed  Health Care     Health Care Equipment        Danvers
#
#              City      Founded
# 0       Minnesota         1902
# 1       Wisconsin         1916
# 2        Illinois         1888
# 3        Illinois  2013 (1888)
# 4   Massachusetts         1981

# %%
# Formatting the 'Founded' column to only contain YEAR data
csv_df['Founded'] = csv_df['Founded'].str[:4]

# %%
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry       Location  \
# 0    MMM           3M  Industrials  Industrial Conglomerates     Saint Paul
# 1    AOS  A. O. Smith  Industrials         Building Products      Milwaukee
# 2    ABT       Abbott  Health Care     Health Care Equipment  North Chicago
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals  North Chicago
# 4   ABMD      Abiomed  Health Care     Health Care Equipment        Danvers
#
#              City Founded
# 0       Minnesota    1902
# 1       Wisconsin    1916
# 2        Illinois    1888
# 3        Illinois    2013
# 4   Massachusetts    1981

# %%
# Fetching number of rows and columns
csv_df.shape
# Out:
# (503, 7)

# %%
# Fetching unique values in each column
csv_df.nunique()
# Out:
# Symbol               503
# Security             503
# GICS Sector           11
# GICS Sub-Industry    122
# Location             238
# City                  49
# Founded              163
# dtype: int64

# %%
# Searching for duplicate entries
csv_df.duplicated().sum()
# Out:
# 0

# %%
# Searching for NULL values in the DataFrame
csv_df.isnull().sum()
# Out:
# Symbol               0
# Security             0
# GICS Sector          0
# GICS Sub-Industry    0
# Location             0
# City                 0
# Founded              0
# dtype: int64

# %%
# Displaying final DataFrame after Data Cleaning
csv_df.head()
# Out:
#   Symbol     Security  GICS Sector         GICS Sub-Industry       Location  \
# 0    MMM           3M  Industrials  Industrial Conglomerates     Saint Paul
# 1    AOS  A. O. Smith  Industrials         Building Products      Milwaukee
# 2    ABT       Abbott  Health Care     Health Care Equipment  North Chicago
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals  North Chicago
# 4   ABMD      Abiomed  Health Care     Health Care Equipment        Danvers
#
#              City Founded
# 0       Minnesota    1902
# 1       Wisconsin    1916
# 2        Illinois    1888
# 3        Illinois    2013
# 4   Massachusetts    1981

# %%
# Data Visualization
ax = csv_df['GICS Sector'].value_counts().plot(kind = 'bar', figsize=(14,8), title="Securities by Sector", color = 'Blue')
ax.set_xlabel("Sectors")
ax.set_ylabel("Frequency")
ax.legend()

# %%
csv_df = csv_df.drop(['GICS Sector', 'Location'], axis=1)

# %%
csv_df.head()
# Out:
#   Symbol     Security         GICS Sub-Industry            City Founded
# 0    MMM           3M  Industrial Conglomerates       Minnesota    1902
# 1    AOS  A. O. Smith         Building Products       Wisconsin    1916
# 2    ABT       Abbott     Health Care Equipment        Illinois    1888
# 3   ABBV       AbbVie           Pharmaceuticals        Illinois    2013
# 4   ABMD      Abiomed     Health Care Equipment   Massachusetts    1981

# %%
# Cleaning existing data from the database
csv_del_query = 'delete from ticker_master where tck_symbol is not null'
mycursor.execute(csv_del_query)
mydb.commit()

# %%
#Iterate into the CSV DataFrame
for i,row in csv_df.iterrows():
    #INSERT query for inserting the data into the database
    csv_sql = "INSERT INTO stockassist.ticker_master VALUES (%s,%s,%s,%s,%s)"
    try:
        #Execute the SQL query
        mycursor.execute(csv_sql, tuple(row))
        print('Ticker Master Record inserted')
        #Commit the executed query
        mydb.commit()
    except:
        #Display message if the record already exists inside the table
        print('Ticker Master Record already exists')
# Out:
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted
# Ticker Master Record inserted

# %% [markdown]
# ### Data Cleaning on Web Scraping DataFrame

# %%
final_web_df.head()
# Out:
#   Symbol             Company   Price Price_Change_Percent PE_Ratio  \
# 0   MSFT           Microsoft  257.22                +0.1%    27.72
# 1   GOOG            Alphabet   95.31                -0.6%    18.93
# 2  GOOGL            Alphabet   95.07                -0.6%    18.88
# 3   AMZN          Amazon.com   91.58                -1.0%    84.06
# 4    UNH  UnitedHealth Group  538.36                +0.0%    26.36
#
#        Market_Cap         Volume Average_Volume
# 0   1.92 trillion  35.04 million  31.30 million
# 1   1.23 trillion  26.17 million  28.88 million
# 2   1.23 trillion  28.40 million  35.06 million
# 3  934.27 billion  69.69 million  76.16 million
# 4  503.02 billion   2.61 million   3.13 million

# %%
# Fetching number of rows and columns
final_web_df.shape
# Out:
# (500, 8)

# %%
# Fetching unique values in each column
final_web_df.nunique()
# Out:
# Symbol                  496
# Company                 493
# Price                   489
# Price_Change_Percent     74
# PE_Ratio                450
# Market_Cap              475
# Volume                  404
# Average_Volume          405
# dtype: int64

# %%
# Searching for duplicate entries
final_web_df.duplicated().sum()
# Out:
# 3

# %%
# Removing duplicate entries from the DataFrame
final_web_df.drop_duplicates(subset="Symbol", keep=False, inplace=True)

# %%
# Replacing 'N/A' value with NULL value
final_web_df['PE_Ratio'] = final_web_df['PE_Ratio'].replace('N/A',None)
final_web_df = final_web_df.where((pd.notnull(final_web_df)), None)

# %%
final_web_df.head()
# Out:
#   Symbol             Company   Price Price_Change_Percent PE_Ratio  \
# 0   MSFT           Microsoft  257.22                +0.1%    27.72
# 1   GOOG            Alphabet   95.31                -0.6%    18.93
# 2  GOOGL            Alphabet   95.07                -0.6%    18.88
# 3   AMZN          Amazon.com   91.58                -1.0%    84.06
# 4    UNH  UnitedHealth Group  538.36                +0.0%    26.36
#
#        Market_Cap         Volume Average_Volume
# 0   1.92 trillion  35.04 million  31.30 million
# 1   1.23 trillion  26.17 million  28.88 million
# 2   1.23 trillion  28.40 million  35.06 million
# 3  934.27 billion  69.69 million  76.16 million
# 4  503.02 billion   2.61 million   3.13 million

# %%
# Searching for NULL values in the DataFrame
final_web_df.isnull().sum()
# Out:
# Symbol                   0
# Company                  0
# Price                    0
# Price_Change_Percent     1
# PE_Ratio                26
# Market_Cap               0
# Volume                   0
# Average_Volume           0
# dtype: int64

# %%
# Displaying the entries which have NULL values in the DataFrame
print(final_web_df[final_web_df.isnull().any(axis = 1)])
# Out:
#     Symbol                             Company   Price Price_Change_Percent  \
# 21      KO                           Coca-Cola   63.99                 None
# 71      BA                              Boeing  188.25                +0.6%
# 86      GE                    General Electric   81.47                -1.6%
# 221    ALL                            Allstate  129.90                -0.3%
# 231   ILMN                            Illumina  209.98                -0.4%
# 254    BKR                        Baker Hughes   28.98                -1.0%
# 265    IFF  International Flavors & Fragrances  105.63                -1.5%
# 267    WBD              Warner Bros. Discovery   10.98                +0.8%
# 272    BAX                Baxter International   52.30                -1.6%
# 293   EBAY                                eBay   43.75                +0.1%
# 326    AES                                 AES   29.24                -0.1%
# 331    STE                              STERIS  193.72                -2.7%
# 339    VTR                              Ventas   46.47                +0.4%
# 355   TTWO       Take-Two Interactive Software  104.81                +0.2%
# 364   CINF                Cincinnati Financial  106.41                -1.1%
# 366   ETSY                                Etsy  132.03                +0.3%
# 396    RCL             Royal Caribbean Cruises   55.28                -0.9%
# 416    UAL                     United Airlines   40.10                -2.6%
# 420    BIO                Bio-Rad Laboratories  429.90                -1.2%
# 449    CZR               Caesars Entertainment   49.69                -5.4%
# 451   CDAY                        Ceridian HCM   69.15                -0.2%
# 454    CCL                      Carnival Co. &    8.93                +0.2%
# 455   WYNN                        Wynn Resorts   86.32                -0.4%
# 468    AAL             American Airlines Group   13.35                -0.8%
# 489   NCLH               Norwegian Cruise Line   15.08                +0.3%
# 495    LNC                    Lincoln National   32.38                -0.3%
# 499   EMBC                             Embecta   35.14                -1.0%
#
#     PE_Ratio      Market_Cap         Volume Average_Volume
# 21     27.94  276.73 billion  12.64 million  16.25 million
# 71      None  111.78 billion   5.67 million   9.03 million
# 86      None   89.02 billion   7.46 million   6.52 million
# 221     None   34.45 billion   1.51 million   1.99 million
# 231     None   33.03 billion   1.17 million   1.32 million
# 254     None   29.23 billion   7.49 million  10.10 million
# 265     None   26.93 billion   3.31 million   1.54 million
# 267     None   26.66 billion  35.11 million  24.25 million
# 272     None   26.37 billion   6.95 million   3.46 million
# 293     None   23.74 billion   5.64 million   6.50 million
# 326     None   19.53 billion   4.00 million   5.39 million
# 331     None   19.34 billion        612,332        539,143
# 339     None   18.57 billion   2.10 million   2.19 million
# 355     None   17.59 billion   1.64 million   2.39 million
# 364     None   16.73 billion        608,503        736,553
# 366     None   16.59 billion   2.69 million   3.94 million
# 396     None   14.11 billion   4.55 million   5.65 million
# 416     None   13.10 billion  13.83 million  11.81 million
# 420     None   12.82 billion        194,372        211,389
# 449     None   10.66 billion   3.25 million   3.64 million
# 451     None   10.49 billion        951,746   1.68 million
# 454     None    9.94 billion  57.44 million  49.49 million
# 455     None    9.78 billion   1.61 million   3.35 million
# 468     None    8.68 billion  33.60 million  36.02 million
# 489     None    6.35 billion  17.45 million  21.03 million
# 495     None    5.48 billion   2.90 million   1.83 million
# 499     None    2.03 billion        390,156        862,897

# %%
# Displaying final DataFrame after Data Cleaning
final_web_df.head()
# Out:
#   Symbol             Company   Price Price_Change_Percent PE_Ratio  \
# 0   MSFT           Microsoft  257.22                +0.1%    27.72
# 1   GOOG            Alphabet   95.31                -0.6%    18.93
# 2  GOOGL            Alphabet   95.07                -0.6%    18.88
# 3   AMZN          Amazon.com   91.58                -1.0%    84.06
# 4    UNH  UnitedHealth Group  538.36                +0.0%    26.36
#
#        Market_Cap         Volume Average_Volume
# 0   1.92 trillion  35.04 million  31.30 million
# 1   1.23 trillion  26.17 million  28.88 million
# 2   1.23 trillion  28.40 million  35.06 million
# 3  934.27 billion  69.69 million  76.16 million
# 4  503.02 billion   2.61 million   3.13 million

# %%
final_web_df = final_web_df.drop(['Company'], axis=1)

# %%
# Cleaning existing data from the database
web_del_query = 'delete from company_details where cmd_symbol is not null'
mycursor.execute(web_del_query)
mydb.commit()

# %%
#Iterate into the Web DataFrame
for i,row in final_web_df.iterrows():
    #INSERT query for inserting the data into the database
    web_sql = "INSERT INTO stockassist.Company_Details VALUES (%s,%s,%s,%s,%s,%s,%s)"
    try:
        #Execute the SQL query
        mycursor.execute(web_sql, tuple(row))
        print(row[0] + ' Company Details Record inserted')
        #Commit the executed query
        mydb.commit()
    except:
        #Display message if the record already exists inside the table
        print(row[0] + ' Company Details Record already exists')
# Out:
# MSFT Company Details Record inserted
# GOOG Company Details Record inserted
# GOOGL Company Details Record inserted
# AMZN Company Details Record inserted
# UNH Company Details Record inserted
# TSLA Company Details Record inserted
# JNJ Company Details Record inserted
# NVDA Company Details Record inserted
# XOM Company Details Record inserted
# V Company Details Record inserted
# WMT Company Details Record inserted
# JPM Company Details Record inserted
# PG Company Details Record inserted
# LLY Company Details Record inserted
# MA Company Details Record inserted
# HD Company Details Record inserted
# CVX Company Details Record inserted
# META Company Details Record inserted
# PFE Company Details Record inserted
# ABBV Company Details Record inserted
# MRK Company Details Record inserted
# KO Company Details Record inserted
# BAC Company Details Record inserted
# PEP Company Details Record inserted
# AVGO Company Details Record inserted
# TMO Company Details Record inserted
# ORCL Company Details Record inserted
# COST Company Details Record inserted
# CSCO Company Details Record inserted
# MCD Company Details Record inserted
# DHR Company Details Record inserted
# ABT Company Details Record inserted
# ACN Company Details Record inserted
# TMUS Company Details Record inserted
# NKE Company Details Record inserted
# NEE Company Details Record inserted
# DIS Company Details Record inserted
# LIN Company Details Record inserted
# BMY Company Details Record inserted
# WFC Company Details Record inserted
# TXN Company Details Record inserted
# UPS Company Details Record inserted
# PM Company Details Record inserted
# ADBE Company Details Record inserted
# VZ Company Details Record inserted
# MS Company Details Record inserted
# CMCSA Company Details Record inserted
# RTX Company Details Record inserted
# AMGN Company Details Record inserted
# HON Company Details Record inserted
# NFLX Company Details Record inserted
# COP Company Details Record inserted
# SCHW Company Details Record inserted
# QCOM Company Details Record inserted
# IBM Company Details Record inserted
# CRM Company Details Record inserted
# T Company Details Record inserted
# UNP Company Details Record inserted
# DE Company Details Record inserted
# CVS Company Details Record inserted
# LOW Company Details Record inserted
# LMT Company Details Record inserted
# ELV Company Details Record inserted
# GS Company Details Record inserted
# CAT Company Details Record inserted
# INTU Company Details Record inserted
# SBUX Company Details Record inserted
# INTC Company Details Record inserted
# SPGI Company Details Record inserted
# AXP Company Details Record inserted
# PLD Company Details Record inserted
# BA Company Details Record inserted
# AMD Company Details Record inserted
# GILD Company Details Record inserted
# ADP Company Details Record inserted
# BLK Company Details Record inserted
# MDT Company Details Record inserted
# AMT Company Details Record inserted
# CI Company Details Record inserted
# ISRG Company Details Record inserted
# SYK Company Details Record inserted
# AMAT Company Details Record inserted
# MDLZ Company Details Record inserted
# TJX Company Details Record inserted
# CB Company Details Record inserted
# C Company Details Record inserted
# GE Company Details Record inserted
# EL Company Details Record inserted
# ADI Company Details Record inserted
# MMC Company Details Record inserted
# NOW Company Details Record inserted
# MO Company Details Record inserted
# PYPL Company Details Record inserted
# NOC Company Details Record inserted
# REGN Company Details Record inserted
# MRNA Company Details Record inserted
# VRTX Company Details Record inserted
# DUK Company Details Record inserted
# BKNG Company Details Record inserted
# SO Company Details Record inserted
# PGR Company Details Record inserted
# EOG Company Details Record inserted
# APD Company Details Record inserted
# BDX Company Details Record inserted
# SLB Company Details Record inserted
# ZTS Company Details Record inserted
# TGT Company Details Record inserted
# MMM Company Details Record inserted
# HCA Company Details Record inserted
# ITW Company Details Record inserted
# CSX Company Details Record inserted
# GD Company Details Record inserted
# WM Company Details Record inserted
# BSX Company Details Record inserted
# CL Company Details Record inserted
# HUM Company Details Record inserted
# EQIX Company Details Record inserted
# FISV Company Details Record inserted
# SHW Company Details Record inserted
# USB Company Details Record inserted
# ETN Company Details Record inserted
# LRCX Company Details Record inserted
# AON Company Details Record inserted
# CME Company Details Record inserted
# PNC Company Details Record inserted
# ATVI Company Details Record inserted
# NSC Company Details Record inserted
# MU Company Details Record inserted
# CCI Company Details Record inserted
# ICE Company Details Record inserted
# OXY Company Details Record inserted
# EMR Company Details Record inserted
# KLAC Company Details Record inserted
# MET Company Details Record inserted
# FCX Company Details Record inserted
# TFC Company Details Record inserted
# DG Company Details Record inserted
# MCO Company Details Record inserted
# GM Company Details Record inserted
# PXD Company Details Record inserted
# F Company Details Record inserted
# MNST Company Details Record inserted
# KDP Company Details Record inserted
# MCK Company Details Record inserted
# PSA Company Details Record inserted
# MPC Company Details Record inserted
# GIS Company Details Record inserted
# SRE Company Details Record inserted
# CHTR Company Details Record inserted
# ADM Company Details Record inserted
# ORLY Company Details Record inserted
# SNPS Company Details Record inserted
# AEP Company Details Record inserted
# MAR Company Details Record inserted
# D Company Details Record inserted
# KHC Company Details Record inserted
# APH Company Details Record inserted
# HSY Company Details Record inserted
# PSX Company Details Record inserted
# CNC Company Details Record inserted
# KMB Company Details Record inserted
# DXCM Company Details Record inserted
# EW Company Details Record inserted
# CTAS Company Details Record inserted
# AIG Company Details Record inserted
# ROP Company Details Record inserted
# FDX Company Details Record inserted
# VLO Company Details Record inserted
# A Company Details Record inserted
# JCI Company Details Record inserted
# CDNS Company Details Record inserted
# ENPH Company Details Record inserted
# AZO Company Details Record inserted
# NXPI Company Details Record inserted
# MSI Company Details Record inserted
# PAYX Company Details Record inserted
# STZ Company Details Record inserted
# CTVA Company Details Record inserted
# AFL Company Details Record inserted
# TRV Company Details Record inserted
# ADSK Company Details Record inserted
# FIS Company Details Record inserted
# RSG Company Details Record inserted
# ECL Company Details Record inserted
# CMG Company Details Record inserted
# EXC Company Details Record inserted
# FTNT Company Details Record inserted
# HES Company Details Record inserted
# MCHP Company Details Record inserted
# SYY Company Details Record inserted
# BIIB Company Details Record inserted
# LHX Company Details Record inserted
# WMB Company Details Record inserted
# AJG Company Details Record inserted
# KMI Company Details Record inserted
# TT Company Details Record inserted
# O Company Details Record inserted
# DVN Company Details Record inserted
# ROST Company Details Record inserted
# ANET Company Details Record inserted
# MSCI Company Details Record inserted
# IQV Company Details Record inserted
# TEL Company Details Record inserted
# SPG Company Details Record inserted
# XEL Company Details Record inserted
# PH Company Details Record inserted
# PRU Company Details Record inserted
# NUE Company Details Record inserted
# NEM Company Details Record inserted
# LVS Company Details Record inserted
# YUM Company Details Record inserted
# COF Company Details Record inserted
# HLT Company Details Record inserted
# CARR Company Details Record inserted
# BK Company Details Record inserted
# DOW Company Details Record inserted
# PCAR Company Details Record inserted
# IDXX Company Details Record inserted
# WBA Company Details Record inserted
# ED Company Details Record inserted
# DD Company Details Record inserted
# ALL Company Details Record inserted
# EA Company Details Record inserted
# AMP Company Details Record inserted
# ODFL Company Details Record inserted
# TDG Company Details Record inserted
# CMI Company Details Record inserted
# ABC Company Details Record inserted
# OTIS Company Details Record inserted
# HAL Company Details Record inserted
# BF.B Company Details Record inserted
# ILMN Company Details Record inserted
# VICI Company Details Record inserted
# MTD Company Details Record inserted
# DLTR Company Details Record inserted
# KEYS Company Details Record inserted
# AME Company Details Record inserted
# RMD Company Details Record inserted
# KR Company Details Record inserted
# WELL Company Details Record inserted
# SBAC Company Details Record inserted
# NDAQ Company Details Record inserted
# PPG Company Details Record inserted
# ROK Company Details Record inserted
# WEC Company Details Record inserted
# PEG Company Details Record inserted
# DHI Company Details Record inserted
# DLR Company Details Record inserted
# CTSH Company Details Record inserted
# ES Company Details Record inserted
# OKE Company Details Record inserted
# CPRT Company Details Record inserted
# STT Company Details Record inserted
# ON Company Details Record inserted
# BKR Company Details Record inserted
# GWW Company Details Record inserted
# ALB Company Details Record inserted
# AWK Company Details Record inserted
# VRSK Company Details Record inserted
# GLW Company Details Record inserted
# FAST Company Details Record inserted
# DFS Company Details Record inserted
# HPQ Company Details Record inserted
# IT Company Details Record inserted
# LYB Company Details Record inserted
# IFF Company Details Record inserted
# ZBH Company Details Record inserted
# WBD Company Details Record inserted
# WTW Company Details Record inserted
# TROW Company Details Record inserted
# LEN Company Details Record inserted
# GPN Company Details Record inserted
# BAX Company Details Record inserted
# APTV Company Details Record inserted
# CDW Company Details Record inserted
# EIX Company Details Record inserted
# URI Company Details Record inserted
# HRL Company Details Record inserted
# GPC Company Details Record inserted
# K Company Details Record inserted
# ARE Company Details Record inserted
# CBRE Company Details Record inserted
# EFX Company Details Record inserted
# MTB Company Details Record inserted
# VMC Company Details Record inserted
# FE Company Details Record inserted
# EQR Company Details Record inserted
# ETR Company Details Record inserted
# FANG Company Details Record inserted
# AVB Company Details Record inserted
# WY Company Details Record inserted
# HIG Company Details Record inserted
# TSCO Company Details Record inserted
# EBAY Company Details Record inserted
# RJF Company Details Record inserted
# FTV Company Details Record inserted
# ULTA Company Details Record inserted
# DTE Company Details Record inserted
# AEE Company Details Record inserted
# TSN Company Details Record inserted
# MKC Company Details Record inserted
# MLM Company Details Record inserted
# LUV Company Details Record inserted
# ANSS Company Details Record inserted
# FITB Company Details Record inserted
# IR Company Details Record inserted
# FRC Company Details Record inserted
# DAL Company Details Record inserted
# PWR Company Details Record inserted
# PPL Company Details Record inserted
# PFG Company Details Record inserted
# VRSN Company Details Record inserted
# EXR Company Details Record inserted
# HPE Company Details Record inserted
# XYL Company Details Record inserted
# CAH Company Details Record inserted
# WAT Company Details Record inserted
# LH Company Details Record inserted
# MOH Company Details Record inserted
# EPAM Company Details Record inserted
# HBAN Company Details Record inserted
# CHD Company Details Record inserted
# DOV Company Details Record inserted
# TDY Company Details Record inserted
# RF Company Details Record inserted
# PAYC Company Details Record inserted
# AES Company Details Record inserted
# CNP Company Details Record inserted
# CTRA Company Details Record inserted
# JBHT Company Details Record inserted
# WRB Company Details Record inserted
# STE Company Details Record inserted
# CFG Company Details Record inserted
# MAA Company Details Record inserted
# WAB Company Details Record inserted
# ROL Company Details Record inserted
# SEDG Company Details Record inserted
# HOLX Company Details Record inserted
# AMCR Company Details Record inserted
# VTR Company Details Record inserted
# MPWR Company Details Record inserted
# CMS Company Details Record inserted
# CAG Company Details Record inserted
# INCY Company Details Record inserted
# NTRS Company Details Record inserted
# CLX Company Details Record inserted
# CF Company Details Record inserted
# PKI Company Details Record inserted
# WST Company Details Record inserted
# IEX Company Details Record inserted
# EXPD Company Details Record inserted
# BBY Company Details Record inserted
# DRI Company Details Record inserted
# TTWO Company Details Record inserted
# MRO Company Details Record inserted
# FOXA Company Details Record inserted
# DGX Company Details Record inserted
# ABMD Company Details Record inserted
# FDS Company Details Record inserted
# BALL Company Details Record inserted
# CPB Company Details Record inserted
# LYV Company Details Record inserted
# CINF Company Details Record inserted
# ATO Company Details Record inserted
# ETSY Company Details Record inserted
# BR Company Details Record inserted
# OMC Company Details Record inserted
# BRO Company Details Record inserted
# SJM Company Details Record inserted
# FOX Company Details Record inserted
# HWM Company Details Record inserted
# COO Company Details Record inserted
# IRM Company Details Record inserted
# FMC Company Details Record inserted
# KEY Company Details Record inserted
# J Company Details Record inserted
# SWKS Company Details Record inserted
# SYF Company Details Record inserted
# MOS Company Details Record inserted
# ALGN Company Details Record inserted
# NVR Company Details Record inserted
# TXT Company Details Record inserted
# PTC Company Details Record inserted
# AVY Company Details Record inserted
# LDOS Company Details Record inserted
# EXPE Company Details Record inserted
# APA Company Details Record inserted
# EVRG Company Details Record inserted
# LKQ Company Details Record inserted
# ESS Company Details Record inserted
# MGM Company Details Record inserted
# RCL Company Details Record inserted
# FLT Company Details Record inserted
# LNT Company Details Record inserted
# AKAM Company Details Record inserted
# TYL Company Details Record inserted
# NTAP Company Details Record inserted
# VTRS Company Details Record inserted
# PEAK Company Details Record inserted
# SIVB Company Details Record inserted
# TECH Company Details Record inserted
# KIM Company Details Record inserted
# BEN Company Details Record inserted
# ZBRA Company Details Record inserted
# NDSN Company Details Record inserted
# TRMB Company Details Record inserted
# L Company Details Record inserted
# UDR Company Details Record inserted
# IP Company Details Record inserted
# JKHY Company Details Record inserted
# NLOK Company Details Record inserted
# UAL Company Details Record inserted
# POOL Company Details Record inserted
# IPG Company Details Record inserted
# DPZ Company Details Record inserted
# BIO Company Details Record inserted
# RE Company Details Record inserted
# HST Company Details Record inserted
# PARA Company Details Record inserted
# LW Company Details Record inserted
# PKG Company Details Record inserted
# MTCH Company Details Record inserted
# CPT Company Details Record inserted
# SNA Company Details Record inserted
# SWK Company Details Record inserted
# TFX Company Details Record inserted
# CE Company Details Record inserted
# GL Company Details Record inserted
# TAP Company Details Record inserted
# WDC Company Details Record inserted
# CHRW Company Details Record inserted
# MAS Company Details Record inserted
# STX Company Details Record inserted
# NI Company Details Record inserted
# HSIC Company Details Record inserted
# REG Company Details Record inserted
# NWS Company Details Record inserted
# CRL Company Details Record inserted
# BXP Company Details Record inserted
# VFC Company Details Record inserted
# NWSA Company Details Record inserted
# MKTX Company Details Record inserted
# JNPR Company Details Record inserted
# KMX Company Details Record inserted
# CZR Company Details Record inserted
# PHM Company Details Record inserted
# CDAY Company Details Record inserted
# EMN Company Details Record inserted
# QRVO Company Details Record inserted
# CCL Company Details Record inserted
# WYNN Company Details Record inserted
# BBWI Company Details Record inserted
# ALLE Company Details Record inserted
# BWA Company Details Record inserted
# WRK Company Details Record inserted
# UHS Company Details Record inserted
# HII Company Details Record inserted
# FFIV Company Details Record inserted
# TPR Company Details Record inserted
# AOS Company Details Record inserted
# PNW Company Details Record inserted
# IVZ Company Details Record inserted
# FRT Company Details Record inserted
# AAL Company Details Record inserted
# AAP Company Details Record inserted
# CMA Company Details Record inserted
# DISH Company Details Record inserted
# CTLT Company Details Record inserted
# HAS Company Details Record inserted
# RHI Company Details Record inserted
# WHR Company Details Record inserted
# FBHS Company Details Record inserted
# SEE Company Details Record inserted
# PNR Company Details Record inserted
# NRG Company Details Record inserted
# SBNY Company Details Record inserted
# RL Company Details Record inserted
# OGN Company Details Record inserted
# ZION Company Details Record inserted
# XRAY Company Details Record inserted
# DVA Company Details Record inserted
# AIZ Company Details Record inserted
# MHK Company Details Record inserted
# GNRC Company Details Record inserted
# NCLH Company Details Record inserted
# DXC Company Details Record inserted
# LUMN Company Details Record inserted
# ALK Company Details Record inserted
# LNC Company Details Record inserted
# PENN Company Details Record inserted
# PVH Company Details Record inserted
# VNO Company Details Record inserted
# EMBC Company Details Record inserted

# %% [markdown]
# ### Data Cleaning on API DataFrame

# %%
daily_df.head()
# Out:
#         Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-01-18   AAPL  168.820190  169.800003  172.539993  169.410004
# 1 2022-01-18   AMZN  158.917496  158.917496  159.734497  157.664505
# 2 2022-01-18   MSFT  299.840424  302.649994  309.799988  301.739990
# 3 2022-01-18   TSLA  343.503326  343.503326  356.929993  338.686676
# 4 2022-01-19   AAPL  165.270798  166.229996  171.080002  165.940002
#
#          Open    Volume
# 0  171.509995  90956700
# 1  159.104996  67292000
# 2  304.070007  42333200
# 3  342.203339  66743400
# 4  170.000000  94815000

# %%
hourly_df.head()
# Out:
#                  Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-12-14 09:30:00   AAPL  146.000000  146.000000  146.654999  145.070007
# 1 2022-12-14 09:30:00   AMZN   93.149902   93.149902   93.379898   92.279999
# 2 2022-12-14 09:30:00   MSFT  260.859985  260.859985  261.000000  256.920013
# 3 2022-12-14 09:30:00   TSLA  158.258606  158.258606  161.619995  157.339996
# 4 2022-12-14 10:30:00   AAPL  146.074997  146.074997  146.384995  145.580002
#
#          Open    Volume
# 0  145.350006   9784672
# 1   92.501999  11490960
# 2  257.130005   5069260
# 3  159.250000  37342162
# 4  146.009995   8606074

# %%
# Fetching number of rows and columns
daily_df.shape
# Out:
# (920, 8)

# %%
hourly_df.shape
# Out:
# (32, 8)

# %%
# Fetching unique values in each column
daily_df.nunique()
# Out:
# Date         230
# Ticker         4
# Adj Close    912
# Close        902
# High         902
# Low          903
# Open         901
# Volume       920
# dtype: int64

# %%
hourly_df.nunique()
# Out:
# Date          8
# Ticker        4
# Adj Close    32
# Close        32
# High         32
# Low          32
# Open         32
# Volume       29
# dtype: int64

# %%
# Searching for duplicate entries
daily_df.duplicated().sum()
# Out:
# 0

# %%
hourly_df.duplicated().sum()
# Out:
# 0

# %%
# Searching for NULL values in the DataFrame
daily_df.isnull().sum()
# Out:
# Date         0
# Ticker       0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
hourly_df.isnull().sum()
# Out:
# Date         0
# Ticker       0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
# Displaying final DataFrame after Data Cleaning
daily_df.head()
# Out:
#         Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-01-18   AAPL  168.820190  169.800003  172.539993  169.410004
# 1 2022-01-18   AMZN  158.917496  158.917496  159.734497  157.664505
# 2 2022-01-18   MSFT  299.840424  302.649994  309.799988  301.739990
# 3 2022-01-18   TSLA  343.503326  343.503326  356.929993  338.686676
# 4 2022-01-19   AAPL  165.270798  166.229996  171.080002  165.940002
#
#          Open    Volume
# 0  171.509995  90956700
# 1  159.104996  67292000
# 2  304.070007  42333200
# 3  342.203339  66743400
# 4  170.000000  94815000

# %%
# Data Visualization
a = daily_df[daily_df.Ticker == 'AAPL'].plot(x = 'Date', y = 'Low', title = 'Daily Low Prices for Apple', figsize=(16,8))
a.legend()

# %%
b = daily_df[daily_df.Ticker == 'TSLA'].plot(kind='scatter',x='Close',y='High', title = 'Comparison of Daily Close and High Prices of Tesla', figsize=(16,8), color='red')

# %%
hourly_df.head()
# Out:
#                  Date Ticker   Adj Close       Close        High         Low  \
# 0 2022-12-14 09:30:00   AAPL  146.000000  146.000000  146.654999  145.070007
# 1 2022-12-14 09:30:00   AMZN   93.149902   93.149902   93.379898   92.279999
# 2 2022-12-14 09:30:00   MSFT  260.859985  260.859985  261.000000  256.920013
# 3 2022-12-14 09:30:00   TSLA  158.258606  158.258606  161.619995  157.339996
# 4 2022-12-14 10:30:00   AAPL  146.074997  146.074997  146.384995  145.580002
#
#          Open    Volume
# 0  145.350006   9784672
# 1   92.501999  11490960
# 2  257.130005   5069260
# 3  159.250000  37342162
# 4  146.009995   8606074

# %%
# Data Visualization
c = hourly_df[hourly_df.Ticker == 'AMZN'].plot(x = 'Date', y = 'High', title = 'Daily Low Prices for Amazon', figsize=(16,8), color = 'orange')

# %%
b = hourly_df[hourly_df.Ticker == 'MSFT'].plot(kind='kde', x='Open', y='Close', title = 'Comparison of Hourly Open and Close Prices of Microsoft', figsize=(16,8), color='green')

# %%
# Cleaning existing data from the database
web_del_query = 'delete from daily_prices where dp_id is not null'
mycursor.execute(web_del_query)
mydb.commit()

# %%
# Cleaning existing data from the database
web_del_query = 'delete from hourly_prices where hp_id is not null'
mycursor.execute(web_del_query)
mydb.commit()

# %%
#Iterate into the Daily DataFrame
for i,row in daily_df.iterrows():
    #INSERT query for inserting the data into the database
    daily_price_sql = "INSERT INTO stockassist.daily_prices(dp_date,dp_ticker,dp_adj_close,dp_close,dp_high,dp_low,dp_open,dp_volume) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
    try:
        #Execute the SQL query
        mycursor.execute(daily_price_sql, tuple(row))
        print('Daily Price Record inserted')
        #Commit the executed query
        mydb.commit()

    except:
        #Display message if the record already exists inside the table
        print('Daily Price Record already exists')
# Out:
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted
# Daily Price Record inserted

# %%
#Iterate into the Hourly DataFrame
for i,row in hourly_df.iterrows():
    #INSERT query for inserting the data into the database
    hourly_sql = "INSERT INTO stockassist.hourly_prices(hp_date,hp_ticker,hp_adj_close,hp_close,hp_high,hp_low,hp_open,hp_volume) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
    try:
        #Execute the SQL query
        mycursor.execute(hourly_sql, tuple(row))
        print('Hourly Price Record inserted')
        #Commit the executed query
        mydb.commit()

    except:
        #Display message if the record already exists inside the table
        print('Hourly Price Record already exists')
# Out:
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
# Hourly Price Record inserted
